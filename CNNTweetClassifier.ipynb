# %%
import os
import pandas as pd
import numpy as np
import random
import re
import nltk
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('rslp')
from nltk.tokenize import wordpunct_tokenize
# from nltk.tokenize import sent_tokenize (Tokenization)
from nltk.probability import FreqDist
from nltk.metrics import ConfusionMatrix
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package stopwords to /Users/joao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package rslp to /Users/joao/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
# %run NLPha
# Out:
# [nltk_data] Downloading package stopwords to /Users/joao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package rslp to /Users/joao/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
#from NLPha import _remove_url, _remove_regex, _replace_emoticons, _tokenize_text 
#from NLPha import _apply_standardization, _remove_stopwords, _apply_stemmer, _untokenize_text, _get_text_cloud
#from NLPha import _get_freq_dist_list, _get_accuracy

# %%
dftreino =  pd.read_csv('data.csv', delimiter=';')
xtreino = list(dftreino.text)

# %%
xtreino = _remove_url(xtreino)

regex_pattern = '@[\w]*'

xtreino = _remove_regex(xtreino, regex_pattern)

emoticon_list = {':))': 'positive_emoticon', ':)': 'positive_emoticon', ':D': 'positive_emoticon', ':(': 'negative_emoticon', ':((': 'negative_emoticon', '8)': 'neutral_emoticon'}

xtreino = _replace_emoticons(xtreino, emoticon_list)

xtreino_tokens = _tokenize_text(xtreino)

xtreino_tokens = _apply_standardization(xtreino_tokens, std_list)

xtreino_tokens = _remove_stopwords(xtreino_tokens, stopword_list)

X = _untokenize_text(xtreino_tokens)

# %%
tweets = dftreino.text
classes = dftreino.isFavorable

# %%
xtreino_tokens
# Out:
# [['hoje',
#   'maiores',
#   'especialistas',
#   'Reforma',
#   'Previdência',
#   'cientista',
#   'político',
#   'pesquisador',
#   'IPEA',
#   'Paulo',
#   'Tafner',
#   'palavras',
#   'sempre',
#   'duras',
#   '“',
#   'Reforma',
#   'Estado',
#   '…'],
#  ['Reforma', 'Bolsonaro', 'massacra', 'mulheres', '!'],
#  ['Ministro',
#   'educação',
#   'condição',
#   'continuar',
#   '!',
#   'Orientar',
#   'escolas',
#   'fazer',
#   'propaganda',
#   'eleitoral',
#   'Bolsonaro',
#   '?',
#   'Dizer',
#   'universidade',
#   'elite',
#   '?',
#   'Defender',
#   'reforma',
#   'previdência',
#   'aumenta',
#   '10',
#   'anos',
#   'idade',
#   'aposentaria',
#   'professoras',
#   '5',
#   'professores',
#   'Vélez',
#   '!'],
#  ['governo',
#   'Bolsonaro',
#   'condição',
#   'política',
#   'aprovar',
#   'retirada',
#   'direitos',
#   'trabalhadores',
#   'brasileiros',
#   'Vamos',
#   'barrar',
#   'Reforma',
#   'Previdência',
#   '!'],
#  ['Reforma', 'Previdência', 'Bolsonaro', 'pior', 'Temer'],
#  ['Dever',
#   'cumprido',
#   'construímos',
#   'bloco',
#   'partidos',
#   'oposição',
#   'PT',
#   'PSB',
#   'PSOL',
#   'REDE',
#   ').',
#   'Apoiamos',
#   'candidato',
#   'comparada',
#   'fala',
#   'outros',
#   'única',
#   'oposição',
#   'Bolsonaro',
#   'Comprometida',
#   'direitos',
#   'sociais',
#   'trabalhistas',
#   'previdenciários',
#   'Convicção',
#   'acertamos',
#   '!'],
#  ['tarde',
#   'sábado',
#   'recebi',
#   'Santarém',
#   'lideranças',
#   'etnia',
#   'Wai',
#   'Wai',
#   'Oriximiná',
#   'grupo',
#   'levou',
#   'demandas',
#   'políticas',
#   'públicas',
#   'aldeias',
#   'Abordamos',
#   'assuntos',
#   'previdência',
#   'educação',
#   'saúde',
#   'Wai',
#   'Wai',
#   'pediram',
#   'ainda',
#   'atenção',
#   'sobre',
#   'surto',
#   'malária',
#   'região',
#   'onde',
#   'moram'],
#  ['RT',
#   'SUSPENSÃO',
#   'TRAMITAÇÃO',
#   'REFORMA',
#   'PREVIDÊNCIA',
#   'reforma',
#   'previdência',
#   'Bolsonaro',
#   'precisa',
#   'ter',
#   'tramitação',
#   'suspensa',
#   '…'],
#  ['Hoje',
#   'primeira',
#   'reunião',
#   'Frente',
#   'Parlamentar',
#   'Agricultura',
#   'Familiar',
#   'FPAF',
#   ').',
#   'objetivo',
#   'promover',
#   'ações',
#   'favor',
#   'agricultores',
#   'familiares',
#   'país',
#   'desde',
#   'defesa',
#   'direitos',
#   'Previdência',
#   'Rural',
#   'busca',
#   'políticas',
#   'apoio',
#   'incentivo',
#   'produção'],
#  ['Bolsonaro',
#   'lança',
#   'campanha',
#   'mentirosa',
#   'conseguir',
#   'apoio',
#   'reforma',
#   'Previdência'],
#  ['“',
#   'ataque',
#   'brutal',
#   'contra',
#   'classe',
#   'trabalhadora',
#   '”,',
#   'diz',
#   'presidente',
#   'CUT',
#   'Vagner',
#   'Freitas'],
#  ['prejudicados',
#   'ganham',
#   'menos',
#   'têm',
#   'expectativa',
#   'vida',
#   'baixa',
#   'entram',
#   'mercado',
#   'cedo',
#   'profissões',
#   'exigem',
#   'esforço',
#   'físico'],
#  ['proposta',
#   'Bolsonaro',
#   'prevê',
#   'obrigatoriedade',
#   'idades',
#   'mínimas',
#   '65',
#   'anos',
#   'homens',
#   '62',
#   'mulheres'],
#  ['reforma',
#   'Previdência',
#   'dificulta',
#   'acesso',
#   'reduz',
#   'valor',
#   'aposentadoria',
#   'diz',
#   'presidente',
#   'CUT',
#   'Vagner',
#   'Freitas'],
#  ['Contamos',
#   'participação',
#   'Secretário',
#   'Especial',
#   'Previdência',
#   'Social',
#   'Rodrigo',
#   'Marinho',
#   'reunião',
#   'desta',
#   'terça',
#   '26',
#   ').',
#   'Recebemos',
#   'informações',
#   'necessárias',
#   'ir',
#   'atrás',
#   'boas',
#   'soluções',
#   'recebimento',
#   'reforma',
#   'ambiente',
#   'rural'],
#  ['reunião',
#   'desta',
#   'terça',
#   'vamos',
#   'receber',
#   'secretário',
#   'especial',
#   'Previdência',
#   'Social',
#   'Rogério',
#   'Marinho',
#   'tratar',
#   'especificamente',
#   'reforma',
#   'meio',
#   'rural',
#   'Vamos',
#   'receber',
#   'imprensa',
#   'antes',
#   'conversa',
#   '12h',
#   'sede',
#   'Brasília'],
#  ['DENÚNCIA',
#   '!',
#   'proposta',
#   'Reforma',
#   'Previdência',
#   'governo',
#   'ameaça',
#   'tribunais',
#   'superiores',
#   'sorrateiro',
#   'movimento',
#   'Palácio',
#   'Planalto',
#   'abre',
#   'espaço',
#   'idade',
#   'aposentadoria',
#   'magistrados',
#   'modificada',
#   'presidente',
#   'poderia',
#   'indicar',
#   'ministros',
#   'STF'],
#  ['DENÚNCIA',
#   '!',
#   'Proposta',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'grave',
#   'ameaça',
#   'independência',
#   'poder',
#   'judiciário',
#   'sobretudo',
#   'Entenda'],
#  ['REFORMA',
#   'PREVIDÊNCIA',
#   'texto',
#   'governo',
#   'chegou',
#   'hoje',
#   'projeto',
#   'justo',
#   '?'],
#  ['caso',
#   'envolvendo',
#   'Ministro',
#   'Educação',
#   'vai',
#   'virar',
#   'escândalo',
#   '?',
#   'Quais',
#   'escândalos',
#   'governo',
#   'passado',
#   '?',
#   'escândalos',
#   'neste',
#   'governo',
#   'geraram',
#   'algum',
#   'prejuízo',
#   'erário',
#   'PT',
#   'geravam',
#   '?',
#   'tal',
#   'focarmos',
#   'Reforma',
#   'Previdência',
#   '?'],
#  ['Todo',
#   'apoio',
#   'solidariedade',
#   'greve',
#   'trabalhadores',
#   'fechamento',
#   'escritório',
#   'Petrobrás',
#   'afeta',
#   'diretamente',
#   '800',
#   'trabalhadores',
#   'Solidariedade',
#   'servidores',
#   'municipais',
#   'previdência',
#   'atacada',
#   'Doria',
#   'Bruno',
#   'Covas',
#   'cruel',
#   '!'],
#  ['cidadão',
#   'todo',
#   'direito',
#   'concordar',
#   'c',
#   '/',
#   'proposta',
#   'governo',
#   'aí',
#   'usar',
#   'popularidade',
#   'remanescente',
#   '/',
#   'enganar',
#   'população',
#   'forma',
#   'irresponsável',
#   'populista',
#   'demais',
#   'jeito',
#   'fala',
#   'parece',
#   'emprego',
#   'dá',
#   'árvores',
#   '!'],
#  ['Obrigado',
#   'Daniel',
#   'Vale',
#   'ouvir',
#   '1o',
#   'vídeo',
#   'série',
#   'sobre',
#   'começamos',
#   'veicular',
#   'mídias',
#   'sociais',
#   '!'],
#  ['RT',
#   'deputado',
#   'federal',
#   'NOVO',
#   'SP',
#   'explicou',
#   'forma',
#   'didática',
#   'inviabilidade',
#   'atual',
#   'sistema',
#   'previdenciár',
#   '…'],
#  ['Previdência',
#   'iceberg',
#   'Brasil',
#   'preste',
#   'colidir',
#   'afundar',
#   'questão',
#   'responsabilidade',
#   'fazer',
#   'reforma',
#   'previdência'],
#  ['Renuncio',
#   'Plano',
#   'Seguridade',
#   'Social',
#   'Congressistas',
#   'PSSC',
#   ').',
#   'preciso',
#   'ser',
#   'coerente',
#   'reforma',
#   'necessária',
#   'urgente',
#   'Queremos',
#   'mesma',
#   'Previdência',
#   'todos',
#   'brasileiros',
#   '!'],
#  ['Reforma',
#   'remédio',
#   'amargo',
#   'Sabemos',
#   'disso',
#   'impede',
#   'pessoa',
#   'entender',
#   'país',
#   'fica',
#   'insolvente',
#   '"',
#   'contra',
#   'reforma',
#   'previdência',
#   'privilegiados',
#   'mal',
#   'informado',
#   '."',
#   'Amoêdo'],
#  ['Pessoal',
#   'hoje',
#   'Ainda',
#   'longo',
#   'caminho',
#   'frente',
#   'garantir',
#   'Reforma',
#   'Previdência',
#   'eficaz',
#   'coerente',
#   'justa',
#   'todos',
#   'brasileiros',
#   'exceção',
#   'Acompanhem',
#   '!'],
#  ['Contando', 'pouco', 'sobre', 'trabalho', 'plenário', 'Live', 'Facebook'],
#  ['Reunião',
#   'agora',
#   'deputados',
#   'Oposição',
#   'discutir',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'Querem',
#   'acabar',
#   'direito',
#   'brasileiro',
#   'aposentar',
#   'vamos',
#   'permitir',
#   'Vai',
#   'ter',
#   'luta',
#   'vai',
#   'ter',
#   'resistência',
#   '!!!',
#   'Foto',
#   'Richard',
#   'Silva',
#   '/',
#   'PCdoB',
#   'Câmara'],
#  ['Brasília',
#   'diretor',
#   'presidente',
#   'SINPOJUD',
#   'Zenildo',
#   'Garcia',
#   'Castro',
#   'diretora',
#   'Maria',
#   'José',
#   'Silva',
#   'Zezé',
#   'discutindo',
#   'principais',
#   'pontos',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'proposta',
#   'irá',
#   'atingir',
#   'servidores',
#   'públicos',
#   'tratando',
#   'demandas',
#   'categoria'],
#  ['RT',
#   'déficit',
#   'criado',
#   'pois',
#   'governo',
#   'retira',
#   '30',
#   '%',
#   'receitas',
#   'Previdência',
#   'através',
#   '…'],
#  ['abordado',
#   'hoje',
#   'MEGA',
#   'EMPRESÁRIO',
#   'disse',
#   'irresponsável',
#   'vote',
#   'favor',
#   'R',
#   'previdência',
#   'Respondi',
#   'reforma',
#   'combate',
#   'privilégio',
#   'atinge',
#   'pobres',
#   'vai',
#   'criar',
#   'caos',
#   'economia',
#   'Irresponsabilidade',
#   'achar',
#   'idoso',
#   'pobre',
#   'pode',
#   'viver',
#   'R',
#   '$',
#   '400'],
#  ['manhã',
#   'hoje',
#   '26',
#   '),',
#   'participei',
#   'reunião',
#   'bancada',
#   'federal',
#   'Partido',
#   'República',
#   'tendo',
#   'pauta',
#   'Reforma',
#   'Previdência',
#   'Durante',
#   'reunião',
#   'reafirmamos',
#   'compromisso',
#   'histórico'],
#  ['imbecilidade',
#   'esconde',
#   'atrás',
#   'perfis',
#   'artificiais',
#   'gera',
#   'pretenso',
#   'direito',
#   'anarquisar',
#   'pessoas',
#   'têm',
#   'pensamentos',
#   'lutar',
#   'contra',
#   'verdadeira',
#   'canalhice',
#   'reforma',
#   'previdenciária',
#   'gerada',
#   'pra',
#   'tirar',
#   'direitos',
#   'quase',
#   'dar',
#   'bancos'],
#  ['“',
#   'risco',
#   'Brasil',
#   'precisamos',
#   'discutir',
#   'exaustivamente',
#   'centrais',
#   'sindicais',
#   'pra',
#   'entender',
#   'vai',
#   'afetar',
#   'população',
#   '”',
#   'André',
#   'Figueiredo',
#   'debate',
#   'PDT',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'Acompanhe'],
#  ['Começou',
#   'agora',
#   'debate',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'sede',
#   'PDT',
#   'participação',
#   '!',
#   'Vamos',
#   'colocar',
#   'evidência',
#   'principais',
#   'pontos',
#   'dessa',
#   'matéria',
#   'importante',
#   'povo',
#   'Acompanhe'],
#  ['proposta',
#   'Reforma',
#   'Previdência',
#   'penaliza',
#   'pobres',
#   'vulneráveis',
#   'mentira',
#   'combate',
#   'privilégio',
#   'Nenhuma',
#   'palavra',
#   'contra',
#   'sonegadores'],
#  ['Secretário',
#   'Previdência',
#   'Rogério',
#   'Marinho',
#   'apresenta',
#   'proposta',
#   'especialmente',
#   'repercussão',
#   'meio',
#   'rural'],
#  ['recebe',
#   'Rogério',
#   'Marinho',
#   'secretário',
#   'debater',
#   'especialmente',
#   'repercussão',
#   'meio',
#   'rural'],
#  ['Hoje',
#   'Brasília',
#   'reunião',
#   'iremos',
#   'debater',
#   'tantos',
#   'importantes',
#   'impacto',
#   'reforma',
#   'Previdência',
#   'campo'],
#  ['governador',
#   'tratando',
#   'sobre',
#   'reforma',
#   'administrativa',
#   'estado',
#   'pautas',
#   'nacionais',
#   'reforma',
#   'previdência',
#   'projeto',
#   'segurança',
#   'pública'],
#  ['Parabéns',
#   'autoproclamado',
#   'Presidente',
#   'Brasil',
#   'primeira',
#   'reivindicação',
#   'retire',
#   'Câmara',
#   'reforma',
#   'previdência',
#   'prejudica',
#   'brasileir',
#   'pobres',
#   'lista',
#   'outros',
#   'retrocessos',
#   'pedirei',
#   'Vossa',
#   'Excelência',
#   'revogue',
#   'seguida'],
#  ['RT',
#   'passar',
#   'vai',
#   'aposentar',
#   'conheça',
#   'efeitos',
#   'nefastos',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   '…'],
#  [],
#  [],
#  ['Possivelmente',
#   'pobres',
#   'morrerão',
#   'antes',
#   'aposentar',
#   'diz',
#   'Adriana',
#   'Marcolino',
#   'Dieese'],
#  [],
#  ['Nova',
#   'Previdência',
#   'tambem',
#   'engloba',
#   'mudanças',
#   'envolvem',
#   'estados',
#   'Exige',
#   'portanto',
#   'comprometimento',
#   'executivos',
#   'legislativos',
#   'estaduais',
#   'faz',
#   'sentido',
#   'omitir',
#   'jogar',
#   'sobre',
#   'Congresso',
#   'Nacional',
#   'toda',
#   'responsabilidade',
#   'debate'],
#  ['Comecei',
#   'debruçar',
#   'sobre',
#   'texto',
#   'Reforma',
#   'Previdência',
#   'vamos',
#   'analisar',
#   'matéria',
#   'cuidado',
#   'técnico',
#   'deputado',
#   'federal',
#   'Pernambuco',
#   'comprometo',
#   'manter',
#   'atenção',
#   'sobre',
#   'diferenças',
#   'sociais',
#   'marcam',
#   'país'],
#  ['pauta',
#   'hoje',
#   'Reforma',
#   'Previdência',
#   'assunto',
#   'precisa',
#   'atenção',
#   'cedo',
#   'entrega',
#   'texto',
#   'presidente',
#   'Câmara',
#   'Federal',
#   'Agora',
#   'sigo',
#   'reunião',
#   'detalhamento',
#   'projeto',
#   'acompanhando',
#   '!'],
#  ['entrar',
#   'mérito',
#   'demissão',
#   'ministro',
#   'Bebianno',
#   'importante',
#   'Brasil',
#   'siga',
#   'caminho',
#   'tranquilidade',
#   'Precisamos',
#   'governo',
#   'envie',
#   'Congresso',
#   'quanto',
#   'antes',
#   'Reforma',
#   'Previdência',
#   'precisa',
#   'ser',
#   'discutida',
#   'serenidade',
#   'seriedade'],
#  ['pouco',
#   'Rodrigo',
#   'Maia',
#   'presidente',
#   'câmara',
#   'conversar',
#   'governador',
#   'Paulo',
#   'Câmara',
#   'sobre',
#   'previdência'],
#  ['Presidente',
#   'Rodrigo',
#   'Maia',
#   'inicia',
#   'hoje',
#   'visitas',
#   'diversos',
#   'governadores',
#   'par',
#   'debater',
#   'previdência',
#   'social',
#   'brasileira'],
#  ['RT',
#   'Texto',
#   'Previdência',
#   'apresentado',
#   'Bolsonaro',
#   'seguro',
#   'diz',
#   'Onyx'],
#  ['momento',
#   'discute',
#   'Reforma',
#   'Previdência',
#   'tira',
#   'direitos',
#   'penaliza',
#   'pobres',
#   'INSS',
#   'gasto',
#   'mensal',
#   'R',
#   '$',
#   '279',
#   'mil',
#   'vítimas',
#   'Brumadinho'],
#  ['forma',
#   'inacreditável',
#   'economista',
#   'Paulo',
#   'Tafner',
#   'afirma',
#   '"',
#   'regras',
#   'injustas',
#   'empregada',
#   'doméstica',
#   'aposenta',
#   'antes',
#   'patroa',
#   '".',
#   'Entenderam',
#   'pensamento',
#   'daqueles',
#   'defendem',
#   'Ref',
#   'Previdência',
#   '?'],
#  ['Veja',
#   '05',
#   'motivos',
#   'dizer',
#   'Reforma',
#   'Previdência',
#   '!',
#   'Compartilhe',
#   '!'],
#  ['povo',
#   'brasileiro',
#   'vai',
#   'permitir',
#   'aprovação',
#   'reforma',
#   'tira',
#   'direitos',
#   'compromete',
#   'futuro'],
#  ['luta', 'todas', 'todos', '!'],
#  ['reforma',
#   'Previdência',
#   'dificulta',
#   'acesso',
#   'reduz',
#   'valor',
#   'aposentadoria'],
#  ['PEC', 'reforma', 'Previdência', 'Bolsonaro', 'pior', 'Temer'],
#  ['Reforma',
#   'Previdência',
#   'reduzirá',
#   'valor',
#   'aposentadoria',
#   'mulheres',
#   'pensões',
#   'viúvos',
#   'órfãos'],
#  ['TIREM',
#   'MÃOS',
#   'PREVIDÊNCIA',
#   '!',
#   'Debate',
#   'Carlos',
#   'gabas',
#   'ex',
#   'ministro',
#   'Previdência',
#   'Social',
#   'governos',
#   'Lula',
#   'Dilma'],
#  ['semana',
#   'debates',
#   'impedir',
#   'aprovação',
#   'Reforma',
#   'Previdência',
#   'governo',
#   'Bolsonaro',
#   'quer',
#   'acabar',
#   'aposentadoria',
#   'rural'],
#  ['semana',
#   'debates',
#   'impedir',
#   'aprovação',
#   'Reforma',
#   'Previdência',
#   'governo',
#   'Bolsonaro',
#   'quer',
#   'acabar',
#   'aposentadoria',
#   'rural'],
#  ['Reforma',
#   'Previdência',
#   'perversa',
#   'trabalhador',
#   'apoio',
#   'ser',
#   'aprovada',
#   'derrota',
#   'governo',
#   'votos',
#   'governo',
#   'começa',
#   'ouvir',
#   'partidos',
#   'negociar',
#   'reforma',
#   'Previdência',
#   'Brasil',
#   '247'],
#  ['aposentado',
#   'pode',
#   'pagar',
#   'conta',
#   'Reposição',
#   'inflação',
#   'ameaçada',
#   'reforma',
#   'previdência',
#   'Brasil',
#   '247'],
#  ['RT',
#   'Maia',
#   'difícil',
#   'tramitar',
#   'PEC',
#   'Previdência',
#   'proposta',
#   'militares'],
#  ['presidente',
#   'tornou',
#   'previdência',
#   'superavitária',
#   'dá',
#   'aula',
#   'receita',
#   'garantir',
#   'aposentadoria',
#   'gerando',
#   'empregos',
#   'investindo',
#   'país',
#   'Estado',
#   'consegue',
#   'equilibrar',
#   'contas',
#   'cortar',
#   'direitos'],
#  ['Previdência', 'Bolsonaro', 'colocará', 'risco', 'vida', 'idosos', 'país'],
#  ['Semana',
#   'Brasília',
#   'começou',
#   'discussões',
#   'torno',
#   'Reforma',
#   'Previdência',
#   'tema',
#   'reunião',
#   'Frente',
#   'Parlamentar',
#   'Agropecuária',
#   'debates',
#   'representantes',
#   'Sindifisco',
#   'assunto',
#   'pautou',
#   'encontro',
#   'PSDB',
#   'Secretário',
#   'Especial',
#   'Previdência',
#   'Trabalho'],
#  ['Participando',
#   'reunião',
#   'bancada',
#   'secretário',
#   'especial',
#   'Previdência',
#   'Trabalho',
#   'debater'],
#  ['Reforma',
#   'Previdência',
#   'medidas',
#   'anticorrupção',
#   'alguns',
#   'temas',
#   'sendo',
#   'debatidos',
#   'nesse',
#   'momento',
#   'reunião',
#   'Executiva',
#   'Nacional',
#   'PSDB',
#   'discutindo',
#   'posição',
#   'bancada',
#   'partido',
#   'diante',
#   'assuntos',
#   'importantes',
#   'Brasil'],
#  ['Presidente',
#   'Jair',
#   'Bolsonaro',
#   'entregou',
#   'Câmara',
#   'Deputados',
#   'proposta',
#   'reforma',
#   'previdência',
#   'mandato',
#   'vai',
#   'estar',
#   'atento',
#   'debater',
#   'mudanças',
#   'defender',
#   'reforma',
#   'justa',
#   'todos'],
#  ['RT',
#   'Olha',
#   'disse',
#   'filho',
#   'Bolsonaro',
#   'sobre',
#   '“',
#   'reforma',
#   '”',
#   'previdência',
#   'antes',
#   'eleições'],
#  ['RT',
#   'REFORMA',
#   'PREVIDÊNCIA',
#   'ACHA',
#   'JUSTO',
#   '?',
#   'vídeo',
#   'didático',
#   'entender',
#   'todas',
#   'questões',
#   'envolvem',
#   'previdência',
#   '…'],
#  ['Auxílio',
#   'mudança',
#   '?',
#   'recebi',
#   'reeleito',
#   'mudei',
#   'Aposentadoria',
#   'especial',
#   'deputados',
#   '?',
#   'aceito',
#   'Política',
#   'profissão',
#   'Pretendo',
#   'aposentar',
#   'Regime',
#   'Geral',
#   'Previdência',
#   'projetos',
#   'acabar',
#   'dois',
#   'privilégios',
#   'Tá',
#   'lá',
#   'votar'],
#  ['capitalização',
#   'detalhada',
#   'Bolsonaro',
#   'sabe',
#   'der',
#   'detalhes',
#   'capitalização',
#   'povo',
#   'entende',
#   'maldade',
#   'pressiona',
#   'contra',
#   'Então',
#   'manobra',
#   'jogar',
#   '/',
#   'Projeto',
#   'Lei',
#   'Complementar',
#   '/',
#   'PLC',
#   'Porque',
#   'PEC',
#   'exige',
#   '308',
#   'votos',
#   'PLC',
#   '257'],
#  ['Gov',
#   'Bolsonaro',
#   'vai',
#   'gastar',
#   'R',
#   '$',
#   '45',
#   'milhões',
#   'propaganda',
#   'tentar',
#   'fazer',
#   'povo',
#   'engolir',
#   'pacote',
#   'antiPrevidência',
#   'ter',
#   'ideia',
#   'dinheiro',
#   'suficiente',
#   'pagar',
#   '45',
#   '090',
#   'aposentadorias',
#   'agricultores',
#   'familiares'],
#  ['1',
#   'cada',
#   '4',
#   'jovens',
#   'emprego',
#   'Brasil',
#   'Taxa',
#   'desemprego',
#   '18',
#   '/',
#   '24',
#   'anos',
#   '25',
#   '2',
#   '%',
#   '4',
#   '°',
#   'trimestre',
#   '/',
#   '2018',
#   'mesmos',
#   'diziam',
#   'reforma',
#   'trabalhista',
#   'iria',
#   'gerar',
#   'emprego',
#   'agora',
#   'mentem',
#   'novo',
#   'aprovar',
#   '"',
#   'reforma',
#   '"',
#   'Previdência'],
#  ['Ex',
#   'ministro',
#   'Previdência',
#   'Miguel',
#   'Rossetto',
#   'vivo',
#   'facebook',
#   'falando',
#   'sobre',
#   'horror',
#   'reforma',
#   'Previdência',
#   'Bolsonaro'],
#  ['Quanto',
#   'estudo',
#   'projeto',
#   'reforma',
#   'Previdência',
#   'Bolsonaro',
#   'convenço',
#   'diante',
#   'grande',
#   'farsa',
#   'chamam',
#   'reforma',
#   'artimanha',
#   'tirar',
#   'trabalha',
#   'passar',
#   'ganha',
#   'trabalhar'],
#  ['primeira',
#   'análise',
#   'sobre',
#   'injustiça',
#   'reforma',
#   'Previdência',
#   'Bolsonaro',
#   'quer',
#   'fazer',
#   'trabalha',
#   'agricultura',
#   'familiar'],
#  ['situação',
#   'entrar',
#   'mercado',
#   'trabalho',
#   'futuro',
#   'pode',
#   'ser',
#   'pior',
#   'ainda',
#   'governo',
#   'implantar',
#   'sistema',
#   'capitalização',
#   'previdenciária',
#   'medida',
#   'agrada',
#   'mercado',
#   'financeiro'],
#  ['bilhões',
#   'renúncia',
#   'fiscal',
#   'comprovam',
#   'cada',
#   'vez',
#   'reforma',
#   'Previdência',
#   'justifica',
#   'menos',
#   'deve',
#   'arcar',
#   'renúncias',
#   'fiscais',
#   'Tesouro',
#   'Nacional',
#   'caixa',
#   'Previdência'],
#  ['Todo',
#   'mundo',
#   'sabe',
#   'latifundiários',
#   'grandes',
#   'empresários',
#   'têm',
#   'dívidas',
#   'enormes',
#   'Previdência',
#   'Agora',
#   'Bolsonaro',
#   'apresentou',
#   'projeto',
#   'reformar',
#   'Previdência',
#   'Sabe',
#   'quantas',
#   'linhas',
#   'tal',
#   'reforma',
#   'dedica',
#   'combate',
#   'sonegação',
#   '?',
#   'NENHUMA',
#   '!'],
#  ['Segundo',
#   'ex',
#   'ministro',
#   'Carlos',
#   'Carlos',
#   'Gabas',
#   '2017',
#   'créditos',
#   'previdenciários',
#   'tributários',
#   'valor',
#   'ultrapassava',
#   'R',
#   '$',
#   '2',
#   'trilhões',
#   '400',
#   'bilhões',
#   'sair',
#   'tudo',
#   'conta',
#   'trabalhador',
#   '?'],
#  ['Visita',
#   'presidente',
#   'Sinpol',
#   '/',
#   'AM',
#   'Jaime',
#   'Lopez',
#   'tratar',
#   'interesses',
#   'categoria',
#   'texto',
#   'Reforma',
#   'Previdência'],
#  ['assunto', 'visita', 'Reforma', 'Previdência', 'pauta', 'Congresso', 'ano'],
#  ['Entrevista',
#   'hoje',
#   'Rádio',
#   'Diário',
#   'Marcos',
#   'Santos',
#   'oportunidade',
#   'abordei',
#   'assuntos',
#   '“',
#   'Reforma',
#   'Previdência',
#   '”,',
#   'proposta',
#   'brevemente',
#   'deverá',
#   'chegar',
#   'Câmara',
#   'Deputados'],
#  ['Reforma',
#   'previdência',
#   'Bolsonaro',
#   'vai',
#   'atingir',
#   'duramente',
#   'idosos',
#   'amapaenses',
#   'Amapá',
#   'todas',
#   'unidades',
#   'federadas',
#   'maior',
#   'dependência',
#   'BPC',
#   'Desigualdade',
#   'faz',
#   'idoso',
#   'Norte',
#   'depender',
#   '10x',
#   'BPC',
#   'Sul'],
#  ['Deputado',
#   'Camilo',
#   'alerta',
#   'proposta',
#   'Governo',
#   'Federal',
#   'reforma',
#   'Previdência',
#   'tira',
#   'direitos',
#   'povo',
#   'Amazônia',
#   '“',
#   'aceitaremos',
#   '”.',
#   'Veja',
#   'vídeo',
#   '!'],
#  ['Antecipando',
#   'vôo',
#   'reunião',
#   'Presidente',
#   'Bolsonaro',
#   'equipe',
#   'econômica',
#   'tratar',
#   'previdência'],
#  ['divulgados', 'dois', 'pontos', 'texto', 'reforma', 'previdenciária'],
#  ['Deputado',
#   'federal',
#   'Capitão',
#   'Augusto',
#   'reúne',
#   'nesta',
#   'manhã',
#   'bancada',
#   'policiais',
#   'militares',
#   'alinhar',
#   'estratégias',
#   'defesa',
#   'direitos',
#   'policiais',
#   'militares',
#   'discussão',
#   'reforma',
#   'previdência'],
#  ['Pacote',
#   'anticrime',
#   'importante',
#   'reforma',
#   'Previdência',
#   'defende',
#   'deputado'],
#  ['lado',
#   'colegas',
#   'parlamentares',
#   'presidente',
#   'Câmara',
#   'Rodrigo',
#   'Maia',
#   'debatendo',
#   'sobre',
#   'metas',
#   'expectativas',
#   'país',
#   'próximos',
#   'anos',
#   'foco',
#   'reforma',
#   'previdência',
#   'Trabalho',
#   'alinhado',
#   'prol',
#   'trazer',
#   'melhorias',
#   'piauienses',
#   'Seguimos',
#   'juntos'],
#  [],
#  ['podemos',
#   'tratar',
#   'todos',
#   'trabalhadores',
#   'mesma',
#   'forma',
#   'porque',
#   'existem',
#   'peculiaridades',
#   'relação',
#   'cada',
#   'Falo',
#   'mulheres',
#   'professores',
#   'profissionais',
#   'segurança',
#   'agricultor',
#   'bem',
#   'todos',
#   'compõe',
#   'população',
#   'brasileira'],
#  ['Hoje',
#   'manhã',
#   'reunido',
#   'governador',
#   'Camilo',
#   'Santana',
#   'juntamente',
#   'bancada',
#   'federal',
#   'secretários',
#   'estado',
#   'Ceará',
#   'Debatemos',
#   'sobre',
#   'projetos',
#   'prioritários',
#   'segurança',
#   'pública',
#   'reforma',
#   'Previdência'],
#  ['Pessoal',
#   'sei',
#   'batido',
#   'nesse',
#   'tema',
#   'Reforma',
#   'Previdência',
#   'aqui',
#   'redes',
#   'assunto',
#   'bastante',
#   'sério',
#   'precisamos',
#   'tratar',
#   'atenção',
#   'devida',
#   '!',
#   'vamos',
#   'pagar',
#   'descaso',
#   'governos',
#   'anteriores',
#   'Veja'],
#  ['Participo',
#   'agora',
#   'audiência',
#   'aqui',
#   'deputados',
#   'militares',
#   'debatermos'],
#  ['Oito', 'perguntas', 'nova', 'Previdência', 'afetaria'],
#  ['loucura',
#   'ontem',
#   'agora',
#   'partiu',
#   'Brasília',
#   '!',
#   'Semana',
#   'promete',
#   'ser',
#   'intensa',
#   'capital',
#   'federal',
#   'ida',
#   'presidente',
#   'Bolsonaro',
#   'levar',
#   'PL',
#   'Previdência'],
#  ['RT',
#   'Entenda',
#   'caminho',
#   'proposta',
#   'reforma',
#   'Previdência',
#   'fará',
#   'Congresso'],
#  ['deve',
#   'receber',
#   'breve',
#   'reforma',
#   'Previdência',
#   'estudarmos',
#   'votarmos',
#   'melhor',
#   'brasileiros',
#   'país',
#   'Queremos',
#   'discutir',
#   'projeto',
#   'sociedade',
#   'país',
#   'precisa',
#   'caminhar',
#   'rumo',
#   'crescimento'],
#  ['Muitos',
#   'guardas',
#   'municipais',
#   'têm',
#   'perguntado',
#   'razão',
#   'incluídos',
#   'regras',
#   'aposentadoria',
#   '/',
#   'policiais',
#   'civis',
#   'federais',
#   'agentes',
#   'penitenciários',
#   'sócioeducativos',
#   'totalmente',
#   'acordo',
#   'farei',
#   'emenda',
#   'projeto',
#   'previdência',
#   'incluindo',
#   'categoria'],
#  ['RT',
#   'surpreende',
#   'CNBB',
#   'mil',
#   'motivos',
#   'falar',
#   'reforma',
#   'previdência',
#   'políticas',
#   'públicas',
#   'Campanha',
#   '…'],
#  ['aprovação',
#   'nova',
#   'previdência',
#   'políticos',
#   'irão',
#   'aposentar',
#   'INSS',
#   '65',
#   'anos',
#   'assim',
#   'todo',
#   'cidadão',
#   'brasileiro',
#   'Fico',
#   'feliz',
#   'pois',
#   'nessa',
#   'luta',
#   'anos',
#   'inclusive',
#   'autor',
#   'emenda',
#   'acaba',
#   'aposentadoria',
#   'ex',
#   'governadores',
#   'prefeitos'],
#  ['site',
#   '“',
#   'Antagonista',
#   '”,',
#   'reafirmei',
#   'considero',
#   'reforma',
#   'previdenciária',
#   'medida',
#   'importante',
#   'crescimento',
#   'BR',
#   'Estarei',
#   'portanto',
#   'pessoalmente',
#   'empenhado',
#   'aprovação',
#   'certeza',
#   'governo',
#   'apresentará',
#   'proposta',
#   'economicamente',
#   'adequada',
#   'socialmente',
#   'justa'],
#  ['Recebi',
#   'muita',
#   'satisfação',
#   'prefeitos',
#   'municípios',
#   'Angelim',
#   'Douglas',
#   'Duarte',
#   'Palmeirina',
#   'Marcelo',
#   'Neves',
#   'Terezinha',
#   'Matheus',
#   'Emídio',
#   'Conversamos',
#   'sobre',
#   'conjuntura',
#   'política',
#   'reforma',
#   'Previdência'],
#  ['pacote',
#   'maldades',
#   'Bolsonaro',
#   'contra',
#   'povo',
#   'fim',
#   'Reportagem',
#   'jornal',
#   'Globo',
#   'hoje',
#   'mostra',
#   'governo',
#   'quer',
#   'tributar',
#   'vale',
#   'alimentação',
#   'brasileiros',
#   'intenção',
#   'PEC',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'almoçar',
#   'paz',
#   'povo',
#   'pode'],
#  ['Bolsonaro',
#   'quer',
#   'acabar',
#   'pagamento',
#   'PIS',
#   'milhões',
#   'trabalhadores',
#   'Recebem',
#   'benefício',
#   'hoje',
#   'ganha',
#   '2',
#   'salários',
#   'proposta',
#   'Bolsonaro',
#   'receberá',
#   'apenas',
#   'ganha',
#   '1',
#   'salário',
#   'ganha',
#   '1',
#   'real',
#   'acima',
#   'salário',
#   'ficará'],
#  ['Bolsonaro',
#   'quer',
#   'diminuir',
#   'míseros',
#   'R',
#   '$',
#   '400',
#   'valor',
#   'benefício',
#   'assistencial',
#   'idosos',
#   'situação',
#   'miséria',
#   'Hoje',
#   'valor',
#   'pago',
#   '1',
#   'salário',
#   'mínimo',
#   'reforma',
#   'Bolsonaro',
#   '1',
#   'salário',
#   'mínimo',
#   'pago',
#   'partir',
#   '70',
#   'anos',
#   'permitiremos',
#   '!'],
#  ['solução',
#   'Reforma',
#   'Previdência',
#   'passa',
#   'cobrar',
#   'dívidas',
#   'sonegadores',
#   'impedir',
#   'desvio',
#   'recursos',
#   'Previdência',
#   'combater',
#   'privilégio',
#   'poucos',
#   'custa',
#   'caro',
#   'Brasil',
#   'rombo',
#   'previdência',
#   'culpa',
#   'pobres'],
#  ['Câmara',
#   'recebeu',
#   'reforma',
#   'previdência',
#   'Bolsonaro',
#   'mandato',
#   'vai',
#   'lutar',
#   'permitir',
#   'Bolsonaro',
#   'mexa',
#   'apenas',
#   'aposentadoria',
#   'pobres',
#   'solução',
#   'cobrar',
#   'dívidas',
#   'combater',
#   'privilégios'],
#  ['RT'],
#  ['Bolsonaro',
#   'veio',
#   'Câmara',
#   'entregar',
#   'reforma',
#   'previdência',
#   'saiu',
#   'falar',
#   'imprensa',
#   'deixando',
#   'jornalistas',
#   'informações',
#   'Bolsonaro',
#   'medo',
#   '?'],
#  ['RT',
#   'Deputado',
#   'Carlos',
#   'Veras',
#   'apresenta',
#   'pacote',
#   'emendas',
#   'MP',
#   'Previdência'],
#  ['Alô',
#   'alô',
#   'Bolsonaro',
#   'povo',
#   'quer',
#   'reforma',
#   'Previdência',
#   'tira',
#   'direitos',
#   'trabalhadores',
#   'beneficiar',
#   'bancos',
#   '!'],
#  ['Bolsonaro',
#   'eleição',
#   'contra',
#   'reforma',
#   'Previdência',
#   'Fez',
#   '67',
#   'discursos',
#   'contra',
#   'mudanças',
#   'aposentadoria',
#   'Agora',
#   'após',
#   'eleição',
#   'favor',
#   'reforma',
#   'vai',
#   'retirar',
#   'direitos',
#   'pobres'],
#  ['reforma',
#   'Previdência',
#   'Bolsonaro',
#   'cruel',
#   'pobres',
#   'segue',
#   'mantendo',
#   'privilégios',
#   'ricos',
#   '!'],
#  ['RT',
#   'vídeo',
#   'sobre',
#   'reforma',
#   'previdência',
#   'ficou',
#   'bom',
#   'Vamos',
#   'quebrar',
#   'bolha',
#   '?',
#   'Compartilhe',
#   'todos',
#   '!',
#   'Vamos',
#   'fazer',
#   '…'],
#  ['Fiz',
#   'hoje',
#   'discurso',
#   'tribuna',
#   'Câmara',
#   'Deputados',
#   'recomendando',
#   'Congresso',
#   'Nacional',
#   'discuta',
#   'ponto',
#   'ponto',
#   'proposta',
#   'Reforma',
#   'Previdência',
#   'apresentada',
#   'governo',
#   '…'],
#  ['Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'Guedes',
#   'prejudicial',
#   'povo',
#   'trabalhador',
#   'necessitado',
#   'especialmente',
#   'cruel',
#   'mulheres',
#   'trabalhadores',
#   'campo',
#   'idosos',
#   'Reforma',
#   '!'],
#  ['Guedes',
#   'prejudicial',
#   'povo',
#   'trabalhador',
#   'necessitado',
#   'especialmente',
#   'cruel',
#   'mulheres',
#   'trabalhadores',
#   'campo',
#   'idosos',
#   'Reforma',
#   '!'],
#  ['RT',
#   'passar',
#   'vai',
#   'aposentar',
#   'conheça',
#   'efeitos',
#   'nefastos',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   '…'],
#  ['deputado',
#   'Célio',
#   'Moura',
#   'alerta',
#   'reforma',
#   'previdência',
#   'prejudicial',
#   'trabalhadores',
#   'trabalhadoras',
#   'Assista',
#   'vídeo',
#   'publicitária',
#   'Magda',
#   'Selma',
#   'Moura',
#   'companheira',
#   'parlamentar',
#   'Especialista',
#   'Direito',
#   'Previdenciário',
#   'explica'],
#  ['CONTRA',
#   'REFORMA',
#   'PREVIDÊNCIA',
#   '"',
#   'permitiremos',
#   'retrocessos',
#   'direitos',
#   'trabalhadores',
#   'aposentados',
#   '"',
#   'Vamos',
#   'junt',
#   '!'],
#  ['Após',
#   'reunião',
#   'demais',
#   'membros',
#   'PSDB',
#   'chegamos',
#   'conclusão',
#   'iremos',
#   'apoiar',
#   'alterações',
#   'BPC',
#   'contidas',
#   'proposta',
#   'Reforma',
#   'Previdência',
#   'tanto',
#   'vamos',
#   'continuar',
#   'estudando',
#   'medidas',
#   'alternativas',
#   'tragam',
#   'benefícios',
#   'justos',
#   'todos'],
#  ['Acabei',
#   'apresentar',
#   'Câmara',
#   'emenda',
#   'constitucional',
#   'prevê',
#   'todos',
#   'atuais',
#   'titulares',
#   'mandato',
#   'eletivo',
#   'passem',
#   'tanto',
#   'beneficiar',
#   'quanto',
#   'contribuir',
#   'igualmente',
#   'todos',
#   'demais',
#   'cidadãos',
#   'Regime',
#   'Geral',
#   'Previdência'],
#  ['leu',
#   'proposta',
#   'reforma',
#   'Previdência',
#   '?',
#   'disponibilizando',
#   'texto',
#   'projeto',
#   'íntegra',
#   'posicionamento',
#   '?',
#   'Acesse',
#   'site',
#   'leia',
#   'projeto',
#   'íntegra',
#   'Responda',
#   'tweet',
#   'opinião',
#   '!'],
#  ['Amigos',
#   'disponibilizando',
#   'proposta',
#   'Governo',
#   'Reforma',
#   'Previdência',
#   'sempre',
#   'falamos',
#   'aproximação',
#   'aqui',
#   'email',
#   'todos',
#   'possam',
#   'fazer',
#   'críticas',
#   'sugestões',
#   'análise',
#   'projeto',
#   'dep',
#   'celsosabino',
#   'leg',
#   'br'],
#  ['atitude',
#   'respeito',
#   'Poder',
#   'Legislativo',
#   'Presidente',
#   'Jair',
#   'Bolsonaro',
#   '()',
#   'vem',
#   'pessoalmente',
#   'Congresso',
#   'Nacional',
#   'entregar',
#   'Proposta',
#   'Reforma',
#   'Previdência'],
#  ['Nesta',
#   'terça',
#   'feira',
#   '12',
#   'participei',
#   'reunião',
#   'governador',
#   'Romeu',
#   'Zema',
#   'discutir',
#   'situação',
#   'fiscal',
#   'estado',
#   'tragédia',
#   'Brumadinho',
#   'modernização',
#   'normas',
#   'segurança',
#   'setor',
#   'Debatemos',
#   'políticas',
#   'prevenção',
#   'combate',
#   'drogas',
#   'reforma',
#   'previdência'],
#  ['Pautas',
#   'convergentes',
#   'Reforma',
#   'Tributária',
#   'Reforma',
#   'Política',
#   'Segurança',
#   'Publica',
#   'aliado',
#   'polícias',
#   'Visita',
#   'deputado',
#   'federal',
#   'partido',
#   'novo'],
#  ['reforma', 'previdência', 'objetivo', 'arrancar', 'diretos', 'pobres'],
#  ['REFORMA',
#   'PREVIDÊNCIA',
#   'Participei',
#   'reunião',
#   'resistência',
#   'Reforma',
#   'Previdência',
#   'Seguridade',
#   'Social',
#   'ocorrida',
#   'nesta',
#   'quarta',
#   'feira',
#   '13',
#   '),',
#   'Plenário',
#   '12',
#   'Câmara',
#   'Deputados'],
#  ['ainda',
#   'gente',
#   'contra',
#   'reforma',
#   'previdência',
#   'acaba',
#   'diferenças',
#   'Desconfie',
#   'deputado',
#   'faz',
#   'demagogia',
#   'tema',
#   'quer',
#   'manter',
#   'privilégios',
#   'poder',
#   'legislativo',
#   'Divergir',
#   'sobre',
#   'alguns',
#   'tópicos',
#   'proposta',
#   'sim',
#   'negar',
#   'reforma',
#   'nunca'],
#  ['Entrei',
#   'PPS',
#   'construção',
#   'projeto',
#   'Dia',
#   '23',
#   '/',
#   '03',
#   'partido',
#   'mudará',
#   'nome',
#   'Cidadania',
#   'novo',
#   'estatuto',
#   'acompanha',
#   'Congresso',
#   'sabe',
#   'PPS',
#   'reformista',
#   'defende',
#   'pautas',
#   'liberais',
#   'Votou',
#   'teto',
#   'gastos',
#   'reforma',
#   'trabalhista',
#   'apoia',
#   'mudanças',
#   'previdência'],
#  ['REFORMA',
#   'PREVIDENCIÁRIA',
#   'caiam',
#   'fake',
#   'news',
#   '!',
#   'argumento',
#   'utilizado',
#   'oposição',
#   'apoiado',
#   'sistema',
#   'inteiro',
#   'alimenta',
#   'deste',
#   'modelo',
#   'previdenciário',
#   'fracassado',
#   'pobres',
#   'pagarão',
#   'reforma',
#   'raso',
#   'passa',
#   'falácia'],
#  ['RT',
#   'Bancada',
#   'tucana',
#   'recebe',
#   'governador',
#   'RS',
#   'debate',
#   'sobre',
#   'pautas',
#   'prioritárias',
#   'reforma',
#   'Previdência',
#   '…'],
#  ['Neste',
#   'momento',
#   'participo',
#   'reunião',
#   'governador',
#   'Eduardo',
#   'Leite',
#   'lado',
#   'colegas',
#   'deputados',
#   'PSDB',
#   'pauta',
#   'Brasil',
#   'precisa',
#   'espera',
#   'todos',
#   'Vamos',
#   'começar',
#   'Reforma',
#   'Previdência'],
#  ['Participei',
#   'pouco',
#   'reunião',
#   'Frente',
#   'Parlamentar',
#   'Agropecuária',
#   'FPA',
#   'presença',
#   'secretário',
#   'especial',
#   'previdência',
#   'trabalho',
#   'Rogério',
#   'Marinho',
#   'pauta',
#   'temas',
#   'discutidos',
#   'reforma',
#   'previdência',
#   'FPA',
#   'prioridades',
#   'legislatura'],
#  ['RT', 'Previdência', 'totalmente', 'injusta', 'insustentável', '?!'],
#  ['RT',
#   'Prioridade',
#   'reforma',
#   'Previdência',
#   'diz',
#   'novo',
#   'presidente',
#   'Senado'],
#  ['Recepcionamos',
#   'Bolsonaro',
#   'câmara',
#   'vestidos',
#   'laranja',
#   'laranjas',
#   'mãos',
#   'governo',
#   'vive',
#   'crise',
#   'ética',
#   'grave',
#   'agora',
#   'apresentou',
#   'explicações',
#   'satisfatórias',
#   'governo',
#   'quer',
#   'retirar',
#   'direitos',
#   'povo',
#   'partir',
#   'Reforma',
#   'Previdência'],
#  ['Reunião',
#   'Câmara',
#   'reunião',
#   'Parlamentares',
#   'comissão',
#   'UPB',
#   'União',
#   'Policiais',
#   'Brasil',
#   'discutir',
#   'impacto',
#   'Reforma',
#   'Previdência',
#   'Servidores',
#   'Policiais'],
#  ['RT',
#   'Pronunciamento',
#   'presidente',
#   'sobre',
#   'proposta',
#   'projeto',
#   'entregue',
#   'hoje',
#   '20',
#   'Congres',
#   '…'],
#  ['Presidente',
#   'entregou',
#   'Câmara',
#   'Deputados',
#   'proposta',
#   'reforma',
#   'Previdência',
#   'ser',
#   'debatida',
#   'Parlamentares',
#   'Vamos',
#   'estudar',
#   'debater',
#   'sociedade',
#   'defender',
#   'reforma',
#   'justa',
#   'todos'],
#  ['debate',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'defendi',
#   'governo',
#   'recue',
#   'alguns',
#   'itens',
#   'BPC',
#   'aposentadoria',
#   'rural',
#   'Queremos',
#   'acabar',
#   'privilégios',
#   'vamos',
#   'aceitar',
#   'direitos',
#   'retirados',
#   'pobres',
#   'trabalhadores',
#   'rurais',
#   'economia',
#   'familiar',
#   'deficientes'],
#  ['MidiaNews',
#   'Projeto',
#   'sobre',
#   'previdência',
#   'precisa',
#   'ser',
#   'aprimorado',
#   'diz',
#   'Dr',
#   'Leonardo',
#   'via'],
#  ['Projeto',
#   'sobre',
#   'reforma',
#   'Previdência',
#   'precisa',
#   'ser',
#   'aprimorado',
#   'Congresso',
#   'avalia',
#   'LEIA'],
#  ['RT',
#   'reforma',
#   'Previdência',
#   'chega',
#   'hoje',
#   'Congresso',
#   'Nacional',
#   'forma',
#   'Proposta',
#   'Emenda',
#   'Constituição',
#   'PEC',
#   ').',
#   'Vo',
#   '…'],
#  ['COLETIVA',
#   'IMPRENSA',
#   'PR',
#   'REFORMA',
#   'PREVIDÊNCIA',
#   'tarde',
#   'desta',
#   'terça',
#   'feira',
#   '26',
#   '),',
#   'participei',
#   'coletiva',
#   'imprensa',
#   'liderança',
#   'Partido',
#   'República',
#   'onde',
#   'líder',
#   'deputado',
#   'federal',
#   '…'],
#  ['Acabei',
#   'participar',
#   'coletiva',
#   'imprensa',
#   'Partido',
#   'República',
#   'onde',
#   'líder',
#   'reafirmou',
#   'posição',
#   'oficial',
#   'PR',
#   'Reforma',
#   'Previdência',
#   'Seguiremos',
#   'tradição',
#   '…'],
#  ['Participei',
#   'nesta',
#   'manhã',
#   '26',
#   'reunião',
#   'bancada',
#   'Partido',
#   'República',
#   'tratar',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'ocasião',
#   'ficou',
#   'decidido',
#   'partido',
#   'admite',
#   'qualquer',
#   '…'],
#  ['REFORMA',
#   'PREVIDÊNCIA',
#   'texto',
#   'apresentado',
#   'parece',
#   'agradar',
#   'ninguém',
#   '!'],
#  ['REFORMA',
#   'PREVIDÊNCIA',
#   'Reconheço',
#   'sistema',
#   'atual',
#   'insustentável',
#   'urgente',
#   'inadiável',
#   'reforma',
#   'votação',
#   'proposta',
#   'dois',
#   'pontos',
#   'principais',
#   'irão',
#   'equilibrar',
#   '…'],
#  ['reforma',
#   'elimina',
#   'aposentadoria',
#   'tempo',
#   'contribuição',
#   '100',
#   '%',
#   'recebida',
#   'após',
#   '40',
#   'anos',
#   'mercado',
#   'trabalho',
#   'Brasil',
#   'fortemente',
#   'marcado',
#   'desemprego',
#   'informalidade',
#   'poucos',
#   'conseguirão',
#   'contribuir',
#   'tanto',
#   'tempo'],
#  ['5',
#   'ABSURDOS',
#   'REFORMA',
#   'PREVIDÊNCIA',
#   'Entenda',
#   'Reforma',
#   'Bolsonaro',
#   'compromete',
#   'futuro',
#   'forma',
#   'possível',
#   'fazer',
#   'diferente',
#   'Compartilhe',
#   '!',
#   'Assine',
#   'abaixo',
#   'assinado',
#   'Vem',
#   'lutar',
#   'gente',
#   '!'],
#  ['gravíssima',
#   'proposta',
#   'capitalização',
#   'proposta',
#   'governo',
#   'Bolsonaro',
#   'reforma',
#   'Previdência',
#   'Neste',
#   'regime',
#   'Estado',
#   'empresas',
#   'contribuem',
#   'sistema',
#   'cada',
#   'poupa',
#   'própria',
#   'aposentadoria',
#   'futuro'],
#  ['bastassem',
#   'baixos',
#   'salários',
#   'péssimas',
#   'condições',
#   'trabalho',
#   'professores',
#   'professoras',
#   'transformaram',
#   'principais',
#   'alvos',
#   'governo',
#   'soluções',
#   'problemas',
#   'reais',
#   'educação',
#   'propõe',
#   'mudanças',
#   'aposentadoria',
#   'categoria'],
#  ['Enquanto',
#   'recebe',
#   'três',
#   'rendimentos',
#   'presidente',
#   'Bolsonaro',
#   'propõe',
#   'reforma',
#   'vai',
#   'inviabilizar',
#   'aposentadoria',
#   'população',
#   'certamente',
#   'ampliará',
#   'miséria',
#   'fome',
#   '!',
#   'Todos',
#   'todas',
#   'luta',
#   'barrar',
#   'reforma',
#   '!'],
#  ['Texto', 'Reforma', 'Previdência', 'apresentado', 'Câmara', 'Deputados'],
#  ['Eduardo',
#   'Costa',
#   'vai',
#   'priorizar',
#   'saúde',
#   'previdência',
#   'mandato',
#   'Câmara',
#   'Veja',
#   'blog',
#   'matéria',
#   'completa'],
#  ['Eduardo',
#   'Costa',
#   'entrevista',
#   'TV',
#   'Câmara',
#   'certeza',
#   'bandeiras',
#   'luta',
#   'vão',
#   'ser',
#   'saúde',
#   'previdência',
#   'social',
#   'meio',
#   'ambiente',
#   'sustentabilidade',
#   'situações',
#   'sempre',
#   'defender',
#   'via'],
#  ['Ops',
#   '!',
#   '1',
#   'Sempre',
#   'defendi',
#   'previdência',
#   'única',
#   'todos',
#   'mudei',
#   '2',
#   'Reforma',
#   'Temer',
#   'nunca',
#   'chegou',
#   'ser',
#   'votada',
#   'derrotada',
#   'operação',
#   'Janot',
#   '/',
#   'Joesley',
#   '3',
#   'contra',
#   'aposentadoria',
#   'deputados',
#   'abri',
#   'mão',
#   'previlégio',
#   'INSS',
#   'Bem',
#   'vindo',
#   'aqui',
#   'mirou',
#   'dep',
#   'errado'],
#  ['enfrentar',
#   'gravíssimo',
#   'problema',
#   'previdência',
#   'primeiro',
#   'passo',
#   'transparência',
#   'total',
#   'números',
#   'mostrando',
#   'onde',
#   'todos',
#   'gargalos',
#   'partir',
#   'daí',
#   'sim',
#   'sociedade',
#   'decidirá',
#   'quais',
#   'caminhos',
#   'necessários'],
#  ['outra',
#   'precisamos',
#   'tomar',
#   'cuidado',
#   'colocar',
#   'tudo',
#   'costas',
#   'segmento',
#   'específico',
#   'servidores',
#   'públicos',
#   'exemplo',
#   'Todos',
#   'buscar',
#   'alternativas',
#   'forma',
#   'equilibrada',
#   'auxiliar',
#   'tomadas',
#   'decisão',
#   'país'],
#  ['referente',
#   'proporcionalidade',
#   'contribuição',
#   'estados',
#   'vista',
#   'estados',
#   'Santa',
#   'Catarina',
#   'maior',
#   'expectativa',
#   'vida',
#   '79',
#   'anos',
#   'Maranhão',
#   'menor',
#   '70',
#   'anos',
#   'Mato',
#   'Grosso',
#   '74',
#   '75'],
#  ['Principalmente',
#   'porque',
#   'hoje',
#   '48',
#   '%',
#   'receita',
#   'líquida',
#   'Governo',
#   'Federal',
#   'destinada',
#   'apenas',
#   'previdência',
#   'precisamos',
#   'atentar',
#   'dois',
#   'pontos',
#   'quais',
#   'empenharei',
#   'propor',
#   'emendas'],
#  ['Hoje',
#   'Presidente',
#   'aqui',
#   'Câmara',
#   'Deputados',
#   'apresentar',
#   'projeto',
#   'Reforma',
#   'Previdência',
#   'Pauta',
#   'sido',
#   'comentada',
#   'últimos',
#   'tempos',
#   'quase',
#   'medida',
#   'inegável',
#   'necessidade',
#   'revê',
#   'la'],
#  ['reforma',
#   'previdenciária',
#   'retira',
#   'Constituição',
#   'reajuste',
#   'aposentadoria',
#   'pensão',
#   'inflação',
#   'maior',
#   'parte',
#   'paga',
#   'valores',
#   'mínimos',
#   'subsistência',
#   'Bolsonaro',
#   'diz',
#   'reforma',
#   'combater',
#   'privilégios',
#   'gente',
#   'pobre',
#   'ficará',
#   'proteção'],
#  ['RT',
#   'melhor',
#   'forma',
#   'resolver',
#   'problema',
#   'Previdência',
#   'gerar',
#   'empregos',
#   'Quanto',
#   'emprego',
#   'salários',
#   'contribuiç',
#   '…'],
#  ['RT',
#   'crueldade',
#   'tamanho',
#   'querer',
#   'fazer',
#   'ajustes',
#   'Previdência',
#   'retirando',
#   'direitos',
#   'trabalhadores',
#   'rurais',
#   'mulheres',
#   '…'],
#  ['Bolsonaro',
#   'equipe',
#   'devem',
#   'utilizar',
#   'notícias',
#   'falsas',
#   'métodos',
#   'publicitários',
#   'mentirosos',
#   'ardilosos',
#   'população',
#   'acredite',
#   'reforma',
#   'Previdência',
#   'necessária',
#   'país',
#   'vai',
#   'quebrar'],
#  ['bilhões',
#   'renúncia',
#   'fiscal',
#   'comprovam',
#   'cada',
#   'vez',
#   'reforma',
#   'Previdência',
#   'justifica',
#   'menos',
#   'deve',
#   'arcar',
#   'renúncias',
#   'fiscais',
#   'Tesouro',
#   'Nacional',
#   'caixa',
#   'Previdência'],
#  ['chama',
#   'atenção',
#   'Bolsonaro',
#   'dizer',
#   'gostaria',
#   'fazer',
#   'reforma',
#   'Previdência',
#   'necessária',
#   'dizer',
#   'coloca',
#   'humilde',
#   'popular',
#   'dói',
#   'nele',
#   'situação',
#   'país',
#   'quebrado',
#   'preciso',
#   'cortar',
#   'privilégios'],
#  ['Bolsonaro',
#   'pretende',
#   'socializar',
#   'miséria',
#   'vai',
#   'mexer',
#   'castas',
#   'deveriam',
#   'ser',
#   'mexidas',
#   'prejudicando',
#   'pobres',
#   'entra',
#   'mercado',
#   'trabalho',
#   'cedo'],
#  ['Reforma',
#   'Previdência',
#   'pode',
#   'ter',
#   'três',
#   'opções',
#   'transição',
#   'todas',
#   'ruins',
#   'Brasil',
#   'poderá',
#   'optar',
#   'modelo',
#   'europeu',
#   'chileno'],
#  ['defender',
#   'proposta',
#   'Previdência',
#   'Bolsonaro',
#   'vai',
#   'dizer',
#   'reforma',
#   'vai',
#   'acabar',
#   'desigualdades',
#   'mentira'],
#  ['Bolsonaro',
#   'lança',
#   'campanha',
#   'mentirosa',
#   'conseguir',
#   'apoio',
#   'reforma',
#   'Previdência',
#   'vão',
#   'fazer',
#   'campanha',
#   'publicitária',
#   'enganar',
#   'vamos',
#   'desconstruir',
#   'mentiras',
#   'Bolsonaro'],
#  ['prejudicados',
#   'ganham',
#   'menos',
#   'têm',
#   'expectativa',
#   'vida',
#   'baixa',
#   'entram',
#   'mercado',
#   'cedo',
#   'profissões',
#   'exigem',
#   'esforço',
#   'físico'],
#  ['proposta',
#   'Bolsonaro',
#   'prevê',
#   'obrigatoriedade',
#   'idades',
#   'mínimas',
#   '65',
#   'anos',
#   'homens',
#   '62',
#   'mulheres'],
#  ['Desafio',
#   'bolsonaristas',
#   'dizerem',
#   'única',
#   'estratégia',
#   'governo',
#   'Bolsonaro',
#   'recuperar',
#   'economia',
#   'superar',
#   'mazela',
#   'desemprego',
#   'galopante',
#   'vale',
#   'dizer',
#   '“',
#   'reforma',
#   'previdência',
#   '”,',
#   'táokey',
#   '?'],
#  ['reunião',
#   'bancada',
#   'mulheres',
#   'PT',
#   'permanente',
#   'resistência',
#   'Mulher',
#   'Reforma',
#   'Previdência',
#   'contra'],
#  ['Entenda',
#   'Reforma',
#   'Previdência',
#   'proposta',
#   'Governo',
#   'Bolsonaro',
#   'QUEREMOS',
#   'SABER',
#   'OPINIÃO',
#   '!',
#   'Leia',
#   '!',
#   'Analise',
#   'avalie',
#   'ponto',
#   'ponto',
#   'Obrigado',
#   '!'],
#  ['Entenda', 'Reforma', 'Previdência', 'proposta', 'Governo', 'Bolsonaro'],
#  ['RT',
#   'Dep',
#   'RN',
#   'destacou',
#   'existe',
#   'ambiente',
#   'favorável',
#   'tramitação',
#   'PEC',
#   'Reforma',
#   'Previdência',
#   '…'],
#  ['RT',
#   'Presidente',
#   'Bolsonaro',
#   'vem',
#   'Câmara',
#   'entregar',
#   'Reforma',
#   'Previdência'],
#  ['análise',
#   'ainda',
#   'preliminar',
#   'discordâncias',
#   'reforma',
#   'previdência',
#   'encaminhado',
#   'Bolsonaro',
#   'Entendo',
#   'prejudica',
#   'professores',
#   'penaliza',
#   'trabalhadores',
#   'rurais',
#   'chega',
#   'ser',
#   'cruel',
#   'idosos',
#   'baixa',
#   'renda',
#   'votarei',
#   'nada',
#   'penalize',
#   'pequenos'],
#  ['Quer',
#   'saber',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   '?',
#   'Paulo',
#   'Guedes',
#   'explica',
#   '!',
#   'VIVO',
#   '!'],
#  ['Petistas',
#   'fazem',
#   'protestos',
#   'contra',
#   'reforma',
#   'previdência',
#   'esquerda',
#   'sempre',
#   'transformando',
#   'melhor',
#   'pior',
#   'Nada',
#   'novidade',
#   'né',
#   '...!!!!'],
#  ['Participei',
#   'entrevista',
#   'Bom',
#   'Dia',
#   'ES',
#   'oportunidade',
#   'falar',
#   'sobre',
#   'importância',
#   'reforma',
#   'Previdência',
#   'país',
#   'pontos',
#   'importantes',
#   'ajustar',
#   'país',
#   'pode',
#   'abrir',
#   'mão',
#   'discutir',
#   'reforma',
#   'abrangente',
#   'combata',
#   'privilégios',
#   'faça',
#   'justiça',
#   'social'],
#  ['8',
#   'março',
#   'momento',
#   'importante',
#   'luta',
#   'contra',
#   'violência',
#   'atinge',
#   'mulheres',
#   'direitos',
#   'contra',
#   'Reforma',
#   'Previdência',
#   'penaliza',
#   'forma',
#   'cruel',
#   'mulheres',
#   'brasileiras'],
#  ['reforma',
#   'previdência',
#   'brutal',
#   'trabalhadores',
#   'principalmente',
#   'mulheres',
#   'idade',
#   'mínima',
#   '65',
#   'anos',
#   '40',
#   'anos',
#   'contribuição',
#   'algo',
#   'próprio',
#   'Bolsonaro',
#   'chamava',
#   'massacre',
#   'enquanto',
#   'deputado',
#   'candidato'],
#  ['reforma',
#   'penalizando',
#   'apenas',
#   'pobres',
#   'proposta',
#   'capitalização',
#   'dinheiro',
#   'contribuições',
#   'administrado',
#   'fundos',
#   'privados',
#   'estratégia',
#   'literalmente',
#   'drenar',
#   'dinheiro',
#   'previdência',
#   'favorecer',
#   'bancos'],
#  ['Precisamos',
#   'falar',
#   'sobre',
#   'reforma',
#   'previdência',
#   'Aqui',
#   'Câmara',
#   'articulando',
#   'fazer',
#   'resistência',
#   'necessária',
#   'Secretário',
#   'Previdência',
#   'disse',
#   'recentemente',
#   'reforma',
#   'combater',
#   'privilégios',
#   'verdade',
#   'Vamos',
#   'explicar'],
#  ['agora',
#   'programa',
#   'Câmara',
#   'Hoje',
#   'TV',
#   'Câmara',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'quer',
#   'fazer',
#   'brasileiros',
#   'após',
#   'contribuir',
#   'vida',
#   'toda',
#   'idosos',
#   'pobres',
#   'achamos',
#   'cobrança',
#   'sonegadores',
#   'Reforma',
#   'Tributária',
#   'c',
#   '/',
#   'taxação',
#   'cima',
#   'urgente',
#   'necessária'],
#  ['Reforma',
#   'Previdência',
#   'importante',
#   'nesse',
#   'sentido',
#   'nao',
#   'resolve',
#   'problemas'],
#  ['reforma',
#   'Previdência',
#   'tornar',
#   'todos',
#   'iguais',
#   'privilégios',
#   'deputado',
#   'federal',
#   'desde',
#   'primeiro',
#   'mandato',
#   'havia',
#   'optado',
#   'ingressar',
#   'regime',
#   'geral',
#   'Previdência',
#   'Acho',
#   'justo',
#   'políticos',
#   'recebam',
#   'qualquer',
#   'cidadão',
#   'comum'],
#  ['Brasil',
#   'precisa',
#   'reforma',
#   'Previdência',
#   'Concordo',
#   '!',
#   'reforma',
#   'favoreça',
#   'pobres',
#   '!'],
#  ['Apesar',
#   'favorável',
#   'reforma',
#   'Previdência',
#   'ainda',
#   'vejo',
#   'preocupação',
#   'situação',
#   'trabalhadores',
#   'rurais',
#   'Além',
#   'disso',
#   'acredito',
#   'proposta',
#   'entregue',
#   'hoje',
#   'Congresso',
#   'deveria',
#   'ter',
#   'incluído',
#   'questão',
#   'militares'],
#  ['participado',
#   'reuniões',
#   'diversos',
#   'governadores',
#   'articular',
#   'texto',
#   'consenso',
#   'sobre',
#   'reforma',
#   'Previdência',
#   'afirmou',
#   'proposta',
#   'pode',
#   'ser',
#   'votada',
#   'junho'],
#  ['Congresso',
#   'Nacional',
#   'recebendo',
#   'neste',
#   'momento',
#   'nova',
#   'proposta',
#   'reforma',
#   'Previdência',
#   'Social',
#   'presidente',
#   'República',
#   'entrega',
#   'texto',
#   'pessoalmente',
#   'presidente',
#   'Câmara'],
#  ['RT',
#   'reforma',
#   'Previdência',
#   'chega',
#   'hoje',
#   'Congresso',
#   'Nacional',
#   'forma',
#   'Proposta',
#   'Emenda',
#   'Constituição',
#   'PEC',
#   ').',
#   'Vo',
#   '…'],
#  ['Impactos',
#   'Reforma',
#   'Previdência',
#   '!',
#   'Reforma',
#   'ampla',
#   'buscando',
#   'detalhar',
#   'cada',
#   'ponto',
#   'antes',
#   'iniciarmos',
#   'votações',
#   'comissões',
#   'plenário',
#   'Assista'],
#  ['Hoje',
#   'reunimos',
#   'bancada',
#   'PSD',
#   'busca',
#   'esclarecer',
#   'sobre',
#   'impactos',
#   'Reforma',
#   'Previdência',
#   'recebemos',
#   'Secretário',
#   'Previdência',
#   'Trabalho',
#   'Rogério',
#   'Marinho',
#   'Reforma',
#   'ampla',
#   'buscando',
#   'detalhar',
#   'cada',
#   'ponto',
#   'antes',
#   'iniciarmos',
#   'votações',
#   'comissões',
#   'plenário'],
#  ['Hoje',
#   'presidente',
#   'entregou',
#   'aqui',
#   'Câmara',
#   'Proposta',
#   'Reforma',
#   'Previdência',
#   'Social',
#   'inúmeras',
#   'mudanças',
#   'precisam',
#   'ser',
#   'analisadas',
#   'faço',
#   'compromisso'],
#  ['RT',
#   'Nenhuma',
#   'outra',
#   'proposta',
#   'reforma',
#   'firme',
#   'contra',
#   'privilégios',
#   'claro',
#   'texto',
#   'Nova',
#   'Previdência',
#   '…'],
#  ['RT',
#   'Dep',
#   'chama',
#   'atenção',
#   'necessidade',
#   'reforma',
#   'Previdência',
#   'ñ',
#   'prejudique',
#   'minorias',
#   'defende',
#   '…'],
#  ['existe',
#   'déficit',
#   'Previdência',
#   '!',
#   'Todo',
#   'final',
#   'ano',
#   '30',
#   '%',
#   'arrecadado',
#   'destinado',
#   'outras',
#   'dívidas',
#   'governo',
#   'federal',
#   'serve',
#   'Bolsonaro',
#   'presidente',
#   'República',
#   '?!',
#   'povo',
#   'brasileiro',
#   'precisa',
#   'saber',
#   'verdade'],
#  ['RT',
#   'Dep',
#   'Gervásio',
#   'Maia',
#   'PSB',
#   'PB',
#   'fala',
#   'sobre',
#   'Previdência',
#   'Social',
#   'dicotomia',
#   'Jair',
#   'Bolsonaro',
#   '…'],
#  ['RT',
#   'gervasiomaia',
#   'defesa',
#   'povo',
#   'questão',
#   'Reforma',
#   'Previdência',
#   'Camara',
#   'Federal',
#   'Brasilia',
#   '/',
#   'df',
#   '…'],
#  ['RT',
#   'Dep',
#   'Gervásio',
#   'Maia',
#   'fala',
#   'sobre',
#   'MP',
#   '871',
#   'proposta',
#   'reforma',
#   'Previdência',
#   'governo',
#   'Bolsonaro',
#   'htt',
#   '…'],
#  ['RT',
#   'agora',
#   'deputados',
#   'votado',
#   'Bananeiras',
#   'GERVÁSIO',
#   'MAIA',
#   'levantou',
#   'contra',
#   'Reforma',
#   'Previdência',
#   'massac',
#   '…'],
#  ['RT',
#   'Proposta',
#   'reforma',
#   'previdência',
#   'Governo',
#   'Federal',
#   'infelizmente',
#   'fortes',
#   'medidas',
#   'contra',
#   'pobres',
#   'frágei',
#   '…'],
#  ['Hoje',
#   'participei',
#   'debate',
#   'sobre',
#   'reforma',
#   'Previdência',
#   'promovido',
#   'proposta',
#   'completamente',
#   'desconexa',
#   'realidade',
#   'grande',
#   'maioria',
#   'brasileiros'],
#  ['defendemos',
#   'manutenção',
#   'alguns',
#   'importantes',
#   'direitos',
#   'adquiridos',
#   'trabalhador',
#   'brasileiro',
#   'Previdência',
#   'Social',
#   'Rural',
#   'papel',
#   'Sindicatos',
#   'entendermos',
#   'verdadeiro',
#   'interlocutor',
#   'segmentos',
#   'representando',
#   'classes'],
#  ['Governo',
#   'Federal',
#   'propostas',
#   'reforma',
#   'Previdência',
#   'mostra',
#   'direcionamento',
#   'Estado',
#   'apenas',
#   'aspecto',
#   'financeiro',
#   'social',
#   'nação',
#   'onde',
#   'desigualdade',
#   'classes',
#   'abissal'],
#  ['PDT',
#   'promove',
#   'nesta',
#   'terça',
#   'feira',
#   '19',
#   '/',
#   '02',
#   '),',
#   'amplo',
#   'debate',
#   'sobre',
#   'Previdência',
#   'Social',
#   'participação',
#   'bancadas',
#   'partido',
#   'Câmara',
#   'Senado',
#   'encontro',
#   '10',
# ...
#   'anos',
#   'Assista',
#   'saiba',
#   '!'],
#  ['Participo',
#   'agora',
#   'debate',
#   'sobre',
#   'reforma',
#   'Previdência',
#   'deputado',
#   'Daniel',
#   'TV',
#   'PSDB'],
#  ['semana',
#   'aliás',
#   'fundamental',
#   'partidos',
#   'd',
#   'oposição',
#   'estratégia',
#   'contra',
#   'Reforma',
#   'Previdência',
#   'grande',
#   'reunião',
#   'preparatória',
#   'quarta',
#   '13',
#   '),',
#   'Câmara',
#   'c',
#   '/',
#   'sindicatos',
#   'movimentos',
#   'base',
#   'contrário',
#   'Governo',
#   'faz',
#   'reunião',
#   'aberta',
#   'imprensa'],
#  ['Conhecedor',
#   'difícil',
#   'situação',
#   'reivindiquei',
#   'calendário',
#   'atendimentos',
#   'Previdência',
#   'Social',
#   'quatros',
#   'municípios',
#   'isolados',
#   'Acre',
#   'Jordão',
#   'Marechal',
#   'Thaumaturgo',
#   'Porto',
#   'Walter',
#   'Santa',
#   'Rosa',
#   'Purus'],
#  ['Audiência',
#   'Pública',
#   'sobre',
#   'PEC',
#   '6',
#   '/',
#   '2019',
#   'PEC',
#   'Previdência',
#   'Início',
#   'mobilização',
#   'rumo',
#   'dia',
#   'nacional',
#   'luta',
#   'dia',
#   '22',
#   'próximo'],
#  ['Assembleia',
#   'lotada',
#   'debate',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'Bom',
#   'início'],
#  ['RT',
#   'Reforma',
#   'Previdência',
#   'vai',
#   'impedir',
#   'aposentadoria',
#   'maioria',
#   'agricultores',
#   'quebrar',
#   'municípios',
#   'pequenos',
#   'médios',
#   'https',
#   ':/…'],
#  ['Chegando', 'Assembleia', 'debatermos', 'Reforma', 'Previdência'],
#  ['dúvidas',
#   'sobre',
#   'Proposta',
#   'Reforma',
#   'Previdência',
#   '?',
#   'Daqui',
#   '15',
#   'minutos',
#   'estaremos',
#   'vivo',
#   'ex',
#   'ministro',
#   'Carlos',
#   'Gabas',
#   'fanpage'],
#  ['Daqui',
#   'pouco',
#   'estaremos',
#   'vivo',
#   'fanpage',
#   'ex',
#   'ministro',
#   'Carlos',
#   'Gabas',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'Acompanhe',
#   '!'],
#  ['prioridade', 'reforma', 'previdência', 'podemos', 'perder', 'tempo', '!'],
#  ['RT', 'esquerda', 'entende', 'reforma', 'Brasil', '!', 'Estudantil'],
#  ['RT',
#   'Dívida',
#   'histórica',
#   'previdência',
#   'Cada',
#   'brasileiro',
#   'nasce',
#   'R',
#   '$',
#   '110',
#   'mil',
#   'pagar',
#   'gerações',
#   'anteriores',
#   'conta',
#   '…'],
#  [],
#  [],
#  ['Amanhã',
#   'farei',
#   'pronunciamento',
#   '20',
#   'minutos',
#   'plenário',
#   'Câmara',
#   'sobre',
#   'ano',
#   'execuções',
#   'Marielle',
#   'Anderson',
#   'sobre',
#   'Reforma',
#   'Previdência',
#   'Iremos',
#   'transmitir',
#   'vivo',
#   'Facebook',
#   'partir',
#   '15h25',
#   'Acompanhe',
#   'redes',
#   '!'],
#  ['RT',
#   'Hoje',
#   '11',
#   '),',
#   '14h',
#   'Assembleia',
#   'discutiremos',
#   '“',
#   'Impacto',
#   'Reforma',
#   'Previdência',
#   'vida',
#   'mulheres',
#   '…'],
#  ['Nordestino',
#   'mostra',
#   'sogro',
#   '80',
#   'anos',
#   'roçado',
#   '“',
#   'Bolsonaro',
#   'tá',
#   'tirando',
#   'vida',
#   '”,',
#   'veja',
#   'vídeo'],
#  ['debatendo',
#   'audiência',
#   'pública',
#   'vários',
#   'parlamentares',
#   'proposta',
#   'destruição',
#   'previdência',
#   'Fotos',
#   'Tiago',
#   'Moura'],
#  ['VIVO',
#   'audiência',
#   'pública',
#   'sobre',
#   'proposta',
#   'destruição',
#   'previdência',
#   'aumentar',
#   'lucro',
#   'bancos',
#   'fundos',
#   'pensão'],
#  ['Precisamos',
#   'rodar',
#   'Brasil',
#   'informar',
#   'população',
#   'sobre',
#   'proposta',
#   'destruir',
#   'previdência',
#   'acabar',
#   'direito',
#   'aposentadoria',
#   'maioria',
#   'povo',
#   'brasileiro',
#   'Fortaleza',
#   'audiência',
#   'pública',
#   'outr',
#   'especialistas',
#   'tema'],
#  ['Bolsonaro',
#   'presidente',
#   'Fake',
#   'News',
#   'procura',
#   'desviar',
#   'atenção',
#   'pessoas',
#   'sobre',
#   'temas',
#   'importantes',
#   'Reforma',
#   'Previdência',
#   'corrupção',
#   'ministros',
#   'governo',
#   'fazendo',
#   'publicações',
#   'falsas',
#   'temas',
#   'relevância'],
#  ['Reforma',
#   'Previdência',
#   'maldade',
#   'mulheres',
#   '!',
#   'Veja',
#   'muda',
#   'proposta',
#   'Reforma',
#   'Previdência',
#   'principalmente',
#   'professoras',
#   'viúvas',
#   'idosas',
#   'trabalhadoras',
#   'rurais'],
#  ['RT',
#   'Ministro',
#   'Economia',
#   'Bolsonaro',
#   'falou',
#   'sobre',
#   'proposta',
#   'reforma',
#   'Previdência',
#   'demonstrou',
#   'importar',
#   '…'],
#  ['3',
#   'Agora',
#   'Jair',
#   'vai',
#   'segurar',
#   'única',
#   'coisa',
#   'pode',
#   'mantê',
#   'lo',
#   'poder',
#   'reforma',
#   'Previdência',
#   'agradar',
#   'ricos',
#   'capital',
#   'financeiro',
#   'tentará',
#   'entregar',
#   'aposentadoria',
#   'trabalhador',
#   'brasileiro',
#   'vamos',
#   'manter',
#   'olhos',
#   'abertos',
#   'Mobilização',
#   '!'],
#  ['vice',
#   'líder',
#   'governo',
#   'vamos',
#   'trabalhar',
#   'várias',
#   'frentes',
#   'prioritárias',
#   'país',
#   'Sabemos',
#   'urgência',
#   'nesse',
#   'momento',
#   'aprovar',
#   'Reforma',
#   'Previdência',
#   'assim',
#   'passar',
#   'iniciaremos',
#   'trabalho',
#   'efetivo',
#   'sobre',
#   'PL',
#   '3722'],
#  ['mesmos',
#   'devedores',
#   'agora',
#   'financiam',
#   'campanha',
#   'convencer',
#   'pobres',
#   '"',
#   'todos',
#   'precisam',
#   'fazer',
#   'sacrifícios',
#   '".',
#   'Meio',
#   'trilhão',
#   'reais',
#   'dívidas',
#   'INSS',
#   'parte',
#   'bancos',
#   'grandes',
#   'empresas',
#   'reforma',
#   'previdência',
#   'farsa',
#   '!'],
#  ['Assista',
#   'Vander',
#   'programa',
#   'Fetems',
#   'Debate',
#   'TV',
#   'Interativa',
#   'entrevista',
#   'Jaime',
#   'Teixeira',
#   'Vander',
#   'falou',
#   'sobre',
#   'prejuízos',
#   'atual',
#   'Reforma',
#   'Previdência',
#   'hoje',
#   'MS',
#   'Urgente',
#   '12h',
#   'canal',
#   '13',
#   '1',
#   'TV',
#   'aberta',
#   'canais',
#   '19',
#   '519',
#   'Net'],
#  ['Reforma', 'Previdência', 'começa', 'tramitar', 'Câmara', 'Deputados'],
#  ['poste', 'eleito', 'fazer', 'reforma', 'previdência'],
#  ['Entenda', '10', 'gráficos', 'desafios', 'reforma', 'Previdência', 'Insper'],
#  ['Foto',
#   'tirada',
#   'filho',
#   'Axel',
#   'agora',
#   'pouco',
#   'estudando',
#   'Reforma',
#   'Previdência'],
#  ['Bom',
#   'dia',
#   'atender',
#   'municípios',
#   'rumo',
#   'Brasília',
#   'semana',
#   'debates',
#   'importantes',
#   'Reforma',
#   'Previdência',
#   '?',
#   'Vamos',
#   'esmiuçar',
#   'perto',
#   '!'],
#  ['2017',
#   '"',
#   'Aprovar',
#   'reforma',
#   '[',
#   'previdência',
#   ']',
#   '65',
#   'anos',
#   'mínimo',
#   'falta',
#   'humanidade',
#   '2019',
#   'Presidente',
#   '"',
#   'bate',
#   'martelo',
#   'defende',
#   'aposentadoria',
#   '65',
#   'anos',
#   'homens',
#   '62',
#   'mulheres'],
#  ['reforma',
#   'previdência',
#   'precisa',
#   'corrigir',
#   'distorções',
#   'acentuar',
#   'pedreiro',
#   'gari',
#   'exemplo',
#   'consegue',
#   'desempenhar',
#   'funções',
#   '65',
#   'anos',
#   '?',
#   'Vamos',
#   'fazer',
#   'debate',
#   'Brasil'],
#  ['Juntas',
#   'vamos',
#   'enfrentar',
#   'ameaças',
#   'governo',
#   'Bolsonaro',
#   'representa',
#   'direitos',
#   'defender',
#   'liberdade',
#   'Lula',
#   'combater',
#   'violência',
#   'contra',
#   'mulher',
#   'impedir',
#   'reforma',
#   'previdência'],
#  ['vivas', 'Marielle', 'defesa', 'previdência', 'democracia', 'direitos', '!'],
#  ['Reunião',
#   'Liderança',
#   'Solidariedade',
#   'partido',
#   'irá',
#   'aguardar',
#   'chegada',
#   'proposta',
#   'Reforma',
#   'Previdência',
#   'Câmara',
#   'poder',
#   'discutir',
#   'posicionar'],
#  ['Fiquem',
#   'certos',
#   'todo',
#   'qualquer',
#   'projeto',
#   'venha',
#   'alguma',
#   'forma',
#   'prejudicar',
#   'trabalhador',
#   'vai',
#   'ter',
#   'posicionamento',
#   'contrário'],
#  ['RT',
#   'Carlos',
#   'Veras',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'vai',
#   'deixar',
#   'povo',
#   'miséria',
#   '…'],
#  ['propor',
#   'Reforma',
#   'Previdência',
#   'penaliza',
#   'pobres',
#   'vez',
#   'combater',
#   'sonegação',
#   'bilionária',
#   'grandes',
#   'empresas',
#   'retirar',
#   'isenções',
#   'fiscais',
#   'presidente',
#   'República',
#   'demonstra',
#   'disposição',
#   'aprofundar',
#   'desigualdade',
#   'social',
#   'invés',
#   'combatê',
#   'la'],
#  ['dia',
#   'intenso',
#   'trabalho',
#   'dei',
#   'entrevista',
#   'TV',
#   'Câmara',
#   'falamos',
#   'sobre',
#   'diversas',
#   'pautas',
#   'importantes',
#   'trecho',
#   'sobre',
#   'reforma',
#   'previdência',
#   'assistiu',
#   'aí',
#   '?…'],
#  ['Bolsonaro',
#   'deputado',
#   'usava',
#   'discurso',
#   'objetivo',
#   'enganar',
#   'povo',
#   'Hoje',
#   'presidente',
#   'Bolsonaro',
#   'mostra',
#   'verdadeira',
#   'face',
#   'previdência',
#   'ainda',
#   'perversa',
#   'proposta',
#   'Temer'],
#  ['Pacto',
#   'federativo',
#   'previdência',
#   'pacote',
#   'segurança',
#   'matérias',
#   'grande',
#   'relevância',
#   'análise',
#   'Congresso',
#   'Nacional',
#   'podemos',
#   'perder',
#   'energias',
#   'brigas',
#   'constroem',
#   'forças',
#   'direcionadas',
#   'debater',
#   'buscar',
#   'soluções'],
#  ['pauta',
#   'sobre',
#   'reforma',
#   'previdência',
#   'reforma',
#   'fiscal',
#   'Estado',
#   'sobre',
#   'Brumadinho',
#   'medidas',
#   'sendo',
#   'tomadas',
#   'proposta',
#   'modernização',
#   'regulação',
#   'setor',
#   'mineração',
#   'segurança',
#   'barragens',
#   'lei',
#   'estadual'],
#  ['RT',
#   'aprovação',
#   'Nova',
#   'Previdência',
#   'Congresso',
#   'Nacional',
#   'condições',
#   'estabilizar',
#   'contas',
#   'potencializar',
#   'i',
#   '…'],
#  ['Pesquisa',
#   'pouca',
#   'utilidade',
#   'prática',
#   'pois',
#   '82',
#   '%',
#   'apoiam',
#   'Reforma',
#   'Previdência',
#   'necessariamente',
#   'enviada',
#   'maioria',
#   'eleita',
#   'segmentos',
#   'infelizmente',
#   'apoiarão',
#   'atingir',
#   'OUTROS'],
#  ['"',
#   'favorável',
#   'reforma',
#   'Previdência',
#   'incluindo',
#   'militares',
#   'serviço',
#   'público',
#   'porque',
#   'regime',
#   'atual',
#   'insustentável',
#   'acredite',
#   'déficit',
#   'idade',
#   'mínima',
#   'exemplo',
#   'ajuste',
#   'apenas',
#   '3',
#   '%',
#   'aposentados',
#   'menos',
#   'd',
#   '65',
#   'anos',
#   'pobres',
#   '"'],
#  ['congresso',
#   'vamos',
#   'ter',
#   'pauta',
#   'prioritária',
#   'reformas',
#   'previdência',
#   'tributária',
#   'retomada',
#   'crescimento',
#   'econômico',
#   'geração',
#   'empregos',
#   'renda'],
#  ['RT',
#   'Dep',
#   'Gervásio',
#   'Maia',
#   'mostra',
#   'contradição',
#   'Bolsonaro',
#   'fala',
#   'sobre',
#   'reforma',
#   'Previdência',
#   '…'],
#  ['RT',
#   'Dep',
#   'Gervásio',
#   'Maia',
#   'PSB',
#   'PB',
#   'alerta',
#   'sobre',
#   'MP',
#   '871',
#   'trata',
#   'benefícios',
#   'previdenciários',
#   '…'],
#  ['Reforma',
#   'Previdência',
#   'ataca',
#   'brutalmente',
#   'pobres',
#   'Pq',
#   'invés',
#   'disso',
#   'governo',
#   'revê',
#   'sistema',
#   'tributário',
#   'injusto',
#   'desigual',
#   'fecha',
#   'cerco',
#   'grandes',
#   'sonegadores',
#   'INSS',
#   'devem',
#   '450',
#   'bilhões',
#   '!?'],
#  [],
#  ['mudança',
#   'Previdência',
#   'rural',
#   'dificulta',
#   'aposentadoria',
#   'fragiliza',
#   'sindicatos',
#   'Estabelecer',
#   '40',
#   'ANOS',
#   'contribuição',
#   'trabalhador',
#   'rural',
#   'ter',
#   'direito',
#   '100',
#   '%',
#   'aposentadoria',
#   'foge',
#   'realidade',
#   'além',
#   'ser',
#   'maldade',
#   'absurda'],
#  ['RT',
#   'Dep',
#   'fala',
#   'sobre',
#   'MP',
#   '871',
#   'proposta',
#   'reforma',
#   'Previdência',
#   'governo',
#   'Bolsonaro',
#   'ht',
#   '…'],
#  ['Antes',
#   'eleição',
#   'Bolsonaro',
#   'dizia',
#   'exigir',
#   'idade',
#   'mínima',
#   '65',
#   'anos',
#   'aposentar',
#   '"',
#   'mínimo',
#   'desumanidade',
#   '".',
#   'eleito',
#   'mudou',
#   'discurso'],
#  ['hoje',
#   '!',
#   'Centrais',
#   'Sindicais',
#   'iniciam',
#   'jornada',
#   'luta',
#   'contra',
#   'retrocessos',
#   'previdência',
#   '!'],
#  ['Ato',
#   'mulheres',
#   'Fortaleza',
#   'reúne',
#   'multidão',
#   'violência',
#   'contra',
#   'mulheres',
#   'fim',
#   'feminicídio',
#   'contra',
#   'Reforma',
#   'Previdência'],
#  ['todo',
#   'interior',
#   'Estado',
#   'Ceará',
#   'mulherada',
#   'ruas',
#   'resistência',
#   'violência',
#   'contra',
#   'mulheres',
#   'contra',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   'Daqui',
#   'pouco',
#   'passeata',
#   'Fortaleza'],
#  ['Guedes',
#   'Reforma',
#   'Previdência',
#   'maior',
#   'desafio',
#   'governo',
#   'parte',
#   'econômica',
#   'Concordo',
#   '!'],
#  ['Presidente',
#   'Rodrigo',
#   'Maia',
#   'afirmou',
#   'assim',
#   'Ministro',
#   'Economia',
#   'Paulo',
#   'Guedes',
#   'encaminhar',
#   'proposta',
#   'Previdência',
#   'vai',
#   'solicitar',
#   'reunião',
#   'fechar',
#   'proposta',
#   'Lei',
#   'Kandir',
#   'Previsão',
#   'abril',
#   'terminar',
#   'votação',
#   'projeto',
#   'Câmara'],
#  ['consenso',
#   'deputados',
#   'tucanos',
#   'Reforma',
#   'Previdência',
#   'deve',
#   'ser',
#   'votada',
#   'quanto',
#   'antes',
#   'nenhuma',
#   'definição',
#   'percepção',
#   'inicial',
#   'PSDB',
#   'deverá',
#   'votar',
#   'favor',
#   'reunião',
#   'discute',
#   'outros',
#   'assuntos',
#   'neste',
#   'momento'],
#  ['Daqui',
#   'pouco',
#   'vem',
#   'Congresso',
#   'entregar',
#   'pessoalmente',
#   'proposta',
#   'Reforma',
#   'Previdência',
#   'Presidente',
#   'Câmara',
#   'aqui',
#   'vamos',
#   'acompanhar',
#   'todos',
#   'trâmites'],
#  ['RT', 'líder', 'governo', 'deputado', 'disse', 'estar', 'otimista', '…'],
#  ['ATENÇÃO',
#   '!',
#   'REFORMA',
#   'PREVIDÊNCIA',
#   'PODE',
#   'COMEÇAR',
#   'MAL',
#   '!',
#   'tribuna',
#   'Câmara',
#   'alertar',
#   'todos',
#   'Reforma',
#   'Previdência',
#   'pode',
#   'começar',
#   'mal',
#   'meio',
#   'aprovação',
#   'matérias',
#   'garantam',
#   'benefícios'],
#  ['Tomara', 'preço', 'pagar', 'Reforma', 'Previdência', 'Tomara', '!'],
#  ['Maria',
#   'Lúcia',
#   'Fattorelli',
#   'Reforma',
#   'Previdência',
#   'Bolsonaro',
#   '“',
#   'interesse',
#   'insaciável',
#   'mercado',
#   'financeiro',
#   '”',
#   'via'],
#  ['Cálculos',
#   'feitos',
#   'ex',
#   'secretário',
#   'previdência',
#   'mostram',
#   '2015',
#   'déficit',
#   'militares',
#   '32',
#   'bi',
#   '44',
#   '8',
#   '%',
#   'rombo',
#   'Acontece',
#   'toda',
#   'dívida',
#   'militares',
#   'reforma',
#   'previdência',
#   'Bolsonaro',
#   'Absurdo'],
#  ['Negociar',
#   'justamente',
#   'calibrar',
#   'propostas',
#   'enviadas',
#   'governo',
#   'Congresso',
#   'evitar',
#   'pautas',
#   'contrárias',
#   'ideais',
#   'partidos',
#   'avancem',
#   'caso',
#   'PRB',
#   'adiantei',
#   'exemplo',
#   'vamos',
#   'discutir',
#   'reforma',
#   'Previdência',
#   'abarque',
#   'todos',
#   'setores',
#   'sociedade'],
#  ['reforma',
#   'Previdência',
#   'fundamental',
#   'País',
#   'desde',
#   'todos',
#   'setores',
#   'inclusive',
#   'administração',
#   'pública',
#   'incluídos',
#   'dúvida',
#   'maior',
#   'desafio',
#   'próximos',
#   'meses'],
#  ['RBA',
#   'lança',
#   'site',
#   'defesa',
#   'direito',
#   'aposentadoria',
#   'Página',
#   'explica',
#   'impactos',
#   'vida',
#   'trabalhadores',
#   '“',
#   'reforma',
#   '”',
#   'Bolsonaro',
#   'passar',
#   'alternativas',
#   'sustentabilidade',
#   'Previdência'],
#  ['estratégia',
#   'manter',
#   'campanha',
#   'eleitoral',
#   'acesa',
#   'empurrar',
#   'corrupção',
#   'família',
#   'Bolsonaro',
#   'mudanças',
#   'Reforma',
#   'Previdência',
#   'atende',
#   'investidores',
#   'campanha',
#   'eleitoral'],
#  ['Líder',
#   'PT',
#   'Câmara',
#   'Deputados',
#   'debaterá',
#   'Fortaleza',
#   '"',
#   'Nova',
#   'Previdência',
#   '"',
#   'Bolsonaro',
#   'Blog',
#   'Eliomar'],
#  ['Cândido',
#   'Bracher',
#   'presidente',
#   'Itaú',
#   'saiu',
#   'campo',
#   'dizer',
#   'minuta',
#   'reforma',
#   'Previdência',
#   '“',
#   'boa',
#   '”,',
#   'precisa',
#   '“',
#   'desenhar',
#   '”.',
#   'reforma',
#   'Bolsonaro',
#   'privatizar',
#   'aposentadoria',
#   'atendendo',
#   'interesses',
#   'bancos'],
#  ['Daqui',
#   'farei',
#   'transmissão',
#   'vivo',
#   'Facebook',
#   'falar',
#   'sobre',
#   'mensagem',
#   'presidencial',
#   'abertura',
#   'trabalhos',
#   'Congresso',
#   'Nacional',
#   'reforma',
#   'previdência'],
#  ['menos',
#   'quatro',
#   'países',
#   'América',
#   'Latina',
#   'têm',
#   'sistemas',
#   'aposentadoria',
#   'regimes',
#   'capitalização',
#   'Chile',
#   'Colômbia',
#   'México',
#   'Peru',
#   'têm',
#   'revisado',
#   'modelos',
#   'últimos',
#   'anos',
#   'alguns',
#   'casos',
#   'proposto',
#   'mudanças',
#   'legislação',
#   'previdenciária'],
#  ['RT',
#   'sabem',
#   'compromisso',
#   'mandato',
#   'participativo',
#   'quero',
#   'ouvir',
#   'sobre',
#   'reforma',
#   'previdência',
#   '…'],
#  ['sabem',
#   'compromisso',
#   'mandato',
#   'participativo',
#   'quero',
#   'ouvir',
#   'sobre',
#   'reforma',
#   'previdência',
#   'Participem',
#   'mandem',
#   'sugestões',
#   'telefone',
#   '95',
#   '99904',
#   '4545',
#   'através',
#   'dep',
#   'sheridan',
#   'leg',
#   'br'],
#  ['Chegou',
#   'hoje',
#   'Congresso',
#   'projeto',
#   'reforma',
#   'Previdência',
#   'governo',
#   'federal',
#   'debate',
#   'amplo',
#   'importante',
#   'país',
#   'participem',
#   'opinem',
#   'apresentem',
#   'sugestões',
#   'possamos',
#   'juntos',
#   'participar',
#   'desse',
#   'importante',
#   'debate'],
#  ['Brasil',
#   'precisa',
#   'reformas',
#   'urgentes',
#   'Algumas',
#   'destas',
#   'reformas',
#   'Previdenciária',
#   'duras',
#   'têm',
#   'acontecer',
#   'claro',
#   'forma',
#   'geral',
#   'atinja',
#   'todos',
#   'proteja',
#   'privilégio',
#   'quer'],
#  ...]

# %%
vocabulary = []
index = dict()
encoded_tweets = []

for tweet in xtreino_tokens:
    encoded_tweet = []

    for word in tweet:
        if word not in index:
            vocabulary.append(word)
            index[word] = len(vocabulary) - 1

    # encoding:
    for word in tweet:
        encoded_tweet.append(index[word])
    encoded_tweets.append(encoded_tweet)
    #print(encoded_review)

# %%
X = encoded_tweets
y = classes

# %%
trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import numpy as np

print("testX.shape:",np.array(X_test).shape) #2500个list.每个list代表一句话
print("testY.shape:",np.array(y_test).shape) #2500个label
print("testX[0]:",X_test[0]) #[17, 25, 10, 406, 26, 14, 56, 61, 62, 323, 4]
print("testY[0]:",y_test[0]) #0
# Out:
# testX.shape: (4026,)
# testY.shape: (4026,)
# testX[0]: [646, 38, 39, 5703, 147, 497, 388, 1937, 5327, 6484, 170, 280, 498, 435, 248, 1399, 182, 776, 55, 21, 19431, 21, 20027]
# testY[0]: 1
# <ipython-input-26-23f7b34a0095>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   print("testX.shape:",np.array(X_test).shape) #2500个list.每个list代表一句话

# %%
import tensorflow as tf
import tflearn
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.conv import conv_1d, global_max_pool
from tflearn.layers.merge_ops import merge
from tflearn.layers.estimator import regression
from tflearn.data_utils import to_categorical, pad_sequences
from tflearn.datasets import imdb
import numpy as np
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# 2.Data preprocessing
# Sequence padding
trainX = pad_sequences(trainX, maxlen=100, value=0.) #padding to max length
testX = pad_sequences(testX, maxlen=100, value=0.)   #padding to max length
# Converting labels to binary vectors
trainY = to_categorical(trainY, nb_classes=2) #y as one hot
testY = to_categorical(testY, nb_classes=2)   #y as one hot

# 3.Building convolutional network
#(shape=None, placeholder=None, dtype=tf.float32,data_preprocessing=None, data_augmentation=None,name="InputData")
network = input_data(shape=[None, 100], name='input') #[None, 100] `input_data` is used as a data entry (placeholder) of a network. This placeholder will be feeded with data when training
network = tflearn.embedding(network, input_dim=10000, output_dim=128) #[None, 100,128].embedding layer for a sequence of ids. network: Incoming 2-D Tensor. input_dim: vocabulary size, oput_dim:embedding size
         #conv_1d(incoming,nb_filter,filter_size)
branch1 = conv_1d(network, 128, 3, padding='valid', activation='relu', regularizer="L2") # [batch_size, new steps1, nb_filters]. padding:"VALID",only ever drops the right-most columns
branch2 = conv_1d(network, 128, 4, padding='valid', activation='relu', regularizer="L2") # [batch_size, new steps2, nb_filters]
branch3 = conv_1d(network, 128, 5, padding='valid', activation='relu', regularizer="L2") # [batch_size, new steps3, nb_filters]
network = merge([branch1, branch2, branch3], mode='concat', axis=1) # merge a list of `Tensor` into a single one.===>[batch_size, new steps1+new step2+new step3, nb_filters]
network = tf.expand_dims(network, 2) #[batch_size, new steps1+new step2+new step3,1, nb_filters] Inserts a dimension of 1 into a tensor's shape
network = global_max_pool(network) #[batch_size, pooled dim]
network = dropout(network, 0.5) #[batch_size, pooled dim]
network = fully_connected(network, 2, activation='softmax') #matmul([batch_size, pooled_dim],[pooled_dim,2])---->[batch_size,2]
network = regression(network, optimizer='adam', learning_rate=0.001,
                     loss='categorical_crossentropy', name='target')
# Training
model = tflearn.DNN(network, tensorboard_verbose=0)
model.fit(trainX, trainY, n_epoch = 5, shuffle=True, validation_set=(testX, testY), show_metric=True, batch_size=32)
print("ended...")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tflearn/initializations.py:164: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tflearn/initializations.py:110: calling UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:538: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ---------------------------------
# Run id: 92DJU2
# Log directory: /tmp/tflearn_logs/
# INFO:tensorflow:Summary name Accuracy/ (raw) is illegal; using Accuracy/__raw_ instead.
# ---------------------------------
# Training samples: 8174
# Validation samples: 4026
# --
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#
# InvalidArgumentError: indices[31,12] = 16826 is not in [0, 10000)
# 	 [[{{node Embedding/embedding_lookup}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-10-1535df0c0e9b> in <module>
#      24 # Training
#      25 model = tflearn.DNN(network, tensorboard_verbose=0)
# ---> 26 model.fit(trainX, trainY, n_epoch = 5, shuffle=True, validation_set=(testX, testY), show_metric=True, batch_size=32)
#      27 print("ended...")
#
# /opt/anaconda3/lib/python3.8/site-packages/tflearn/models/dnn.py in fit(self, X_inputs, Y_targets, n_epoch, validation_set, show_metric, batch_size, shuffle, snapshot_epoch, snapshot_step, excl_trainops, validation_batch_size, run_id, callbacks)
#     194         # Retrieve data preprocesing and augmentation
#     195         daug_dict, dprep_dict = self.retrieve_data_preprocessing_and_augmentation()
# --> 196         self.trainer.fit(feed_dicts, val_feed_dicts=val_feed_dicts,
#     197                          n_epoch=n_epoch,
#     198                          show_metric=show_metric,
#
# /opt/anaconda3/lib/python3.8/site-packages/tflearn/helpers/trainer.py in fit(self, feed_dicts, n_epoch, val_feed_dicts, show_metric, snapshot_step, snapshot_epoch, shuffle_all, dprep_dict, daug_dict, excl_trainops, run_id, callbacks)
#     339                             caller.on_sub_batch_begin(self.training_state)
#     340
# --> 341                             snapshot = train_op._train(self.training_state.step,
#     342                                                        (bool(self.best_checkpoint_path) | snapshot_epoch),
#     343                                                        snapshot_step,
#
# /opt/anaconda3/lib/python3.8/site-packages/tflearn/helpers/trainer.py in _train(self, training_step, snapshot_epoch, snapshot_step, show_metric)
#     825         feed_batch = self.train_dflow.next()
#     826         tflearn.is_training(True, session=self.session)
# --> 827         _, train_summ_str = self.session.run([self.train, self.summ_op],
#     828                                              feed_batch)
#     829
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1366
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#    1370     else:
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1392                     '\nsession_config.graph_options.rewrite_options.'
#    1393                     'disable_meta_optimizer = True')
# -> 1394       raise type(e)(node_def, op, message)
#    1395
#    1396   def _extend_graph(self):
#
# InvalidArgumentError: indices[31,12] = 16826 is not in [0, 10000)
# 	 [[node Embedding/embedding_lookup (defined at /opt/anaconda3/lib/python3.8/site-packages/tflearn/layers/embedding_ops.py:62) ]]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node Embedding/embedding_lookup:
#  Embedding/Cast (defined at /opt/anaconda3/lib/python3.8/site-packages/tflearn/layers/embedding_ops.py:61)
#  Embedding/W/read (defined at /opt/anaconda3/lib/python3.8/site-packages/tflearn/variables.py:57)
#
# Original stack trace for 'Embedding/embedding_lookup':
#   File "/opt/anaconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/anaconda3/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "/opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/opt/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2877, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-1535df0c0e9b>", line 12, in <module>
#     network = tflearn.embedding(network, input_dim=10000, output_dim=128) #[None, 100,128].embedding layer for a sequence of ids. network: Incoming 2-D Tensor. input_dim: vocabulary size, oput_dim:embedding size
#   File "/opt/anaconda3/lib/python3.8/site-packages/tflearn/layers/embedding_ops.py", line 62, in embedding
#     inference = tf.nn.embedding_lookup(W, inference,
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/embedding_ops.py", line 322, in embedding_lookup
#     return _embedding_lookup_and_transform(
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/embedding_ops.py", line 138, in _embedding_lookup_and_transform
#     array_ops.gather(params[0], ids, name=name), ids, max_norm)
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py", line 4815, in gather
#     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py", line 3800, in gather_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 3528, in _create_op_internal
#     ret = Operation(
#   File "/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 1990, in __init__
#     self._traceback = tf_stack.extract_stack()
