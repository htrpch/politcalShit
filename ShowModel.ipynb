# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# # Vamos rodar o modelo!

# %%
from models import SimulateStatement, Model, ModelStats

# %%
Experimento = ModelStats("DATA_FINAL.csv")

lambd = 0.6
delta = 0.3
lag = 10

# %%
changes,  Plista, tot_sets = Experimento.get_changes_df_interval(lambd,delta,lag)
# Out:
# 1219

# %% [markdown]
# ## Checando estrutura

# %%
#print(changes)
#print(Plista)
#print(tot_sets)

# %%
Experimento.time[::10]
# Out:
# ['2019-01-02 18:23:13',
#  '2019-02-18 22:37:29',
#  '2019-02-20 15:18:43',
#  '2019-02-21 13:49:12',
#  '2019-02-25 14:49:38',
#  '2019-02-26 20:41:10',
#  '2019-02-28 13:10:53',
#  '2019-03-04 19:53:20',
#  '2019-03-08 11:09:26',
#  '2019-03-09 18:04:55',
#  '2019-03-11 19:47:06',
#  '2019-03-13 14:37:13',
#  '2019-03-15 11:00:08',
#  '2019-03-17 19:10:47',
#  '2019-03-19 13:05:12',
#  '2019-03-20 16:44:41',
#  '2019-03-21 14:23:14',
#  '2019-03-22 13:20:59',
#  '2019-03-22 14:52:38',
#  '2019-03-22 16:54:49',
#  '2019-03-22 19:30:13',
#  '2019-03-22 22:16:16',
#  '2019-03-23 21:15:46',
#  '2019-03-25 12:49:20',
#  '2019-03-26 11:42:05',
#  '2019-03-26 17:52:09',
#  '2019-03-27 00:58:05',
#  '2019-03-28 13:09:08',
#  '2019-03-29 17:37:19',
#  '2019-04-01 17:03:32',
#  '2019-04-02 23:55:38',
#  '2019-04-03 19:06:34',
#  '2019-04-04 00:11:31',
#  '2019-04-04 19:51:25',
#  '2019-04-06 02:30:19',
#  '2019-04-08 20:30:30',
#  '2019-04-09 22:39:23',
#  '2019-04-11 09:45:15',
#  '2019-04-12 15:57:58',
#  '2019-04-15 11:31:50',
#  '2019-04-16 11:29:21',
#  '2019-04-16 22:03:00',
#  '2019-04-17 15:01:54',
#  '2019-04-18 10:27:08',
#  '2019-04-20 17:23:22',
#  '2019-04-22 11:14:11',
#  '2019-04-22 23:27:51',
#  '2019-04-23 19:12:36',
#  '2019-04-24 00:18:18',
#  '2019-04-24 10:45:49',
#  '2019-04-24 18:30:29',
#  '2019-04-25 13:38:55',
#  '2019-04-26 01:01:35',
#  '2019-04-27 21:36:34',
#  '2019-04-29 18:08:59',
#  '2019-05-01 13:40:00',
#  '2019-05-01 22:40:14',
#  '2019-05-03 20:47:37',
#  '2019-05-06 18:02:28',
#  '2019-05-07 19:15:24',
#  '2019-05-08 18:17:05',
#  '2019-05-09 13:47:20',
#  '2019-05-10 19:25:02',
#  '2019-05-13 00:28:12',
#  '2019-05-14 16:13:49',
#  '2019-05-15 17:14:25',
#  '2019-05-17 12:29:50',
#  '2019-05-20 04:00:00',
#  '2019-05-21 02:25:59',
#  '2019-05-22 13:02:10',
#  '2019-05-23 01:23:53',
#  '2019-05-25 12:01:56',
#  '2019-05-27 20:11:27',
#  '2019-05-29 19:43:51',
#  '2019-05-30 21:49:20',
#  '2019-06-02 14:30:00',
#  '2019-06-04 01:00:57',
#  '2019-06-04 14:45:00',
#  '2019-06-04 16:35:00',
#  '2019-06-04 22:00:00',
#  '2019-06-05 23:14:29',
#  '2019-06-07 13:25:43',
#  '2019-06-07 16:40:53',
#  '2019-06-08 23:21:29',
#  '2019-06-11 17:04:47',
#  '2019-06-12 17:27:05',
#  '2019-06-13 13:28:24',
#  '2019-06-13 18:04:14',
#  '2019-06-14 12:56:01',
#  '2019-06-14 20:40:00',
#  '2019-06-17 10:45:33',
#  '2019-06-18 15:35:00',
#  '2019-06-18 22:26:45',
#  '2019-06-22 14:50:39',
#  '2019-06-25 17:36:15',
#  '2019-06-27 15:36:50',
#  '2019-06-30 22:12:34',
#  '2019-07-01 21:41:27',
#  '2019-07-02 22:25:06',
#  '2019-07-03 15:05:00',
#  '2019-07-03 22:28:39',
#  '2019-07-04 13:54:06',
#  '2019-07-04 17:49:49',
#  '2019-07-04 21:01:42',
#  '2019-07-05 10:24:22',
#  '2019-07-07 00:31:38',
#  '2019-07-08 23:24:38',
#  '2019-07-09 13:21:29',
#  '2019-07-09 14:17:37',
#  '2019-07-09 15:30:24',
#  '2019-07-09 18:03:34',
#  '2019-07-09 21:21:09',
#  '2019-07-10 00:51:28',
#  '2019-07-10 04:37:47',
#  '2019-07-10 14:20:00',
#  '2019-07-10 16:10:07',
#  '2019-07-10 18:18:10',
#  '2019-07-10 20:20:24',
#  '2019-07-10 21:51:25',
#  '2019-07-10 23:12:37',
#  '2019-07-11 00:40:57',
#  '2019-07-11 13:17:49']

# %% [markdown]
# # Contando todos os politicos mesmo os não declarantes

# %%
plt.figure(figsize=(10,7))

plt.title('Opinions Sets Evolution λ = 0.6, δ = 0.3', fontsize = 20)

plt.plot(np.transpose(tot_sets)[0], label = 'number of politicians in A')

plt.plot(np.transpose(tot_sets)[1], label = 'number of politicians in O')

plt.plot(np.transpose(tot_sets)[2], label = 'number of politicians in K')

plt.legend()

# %% [markdown]
# # Contando apenas os que se declaram no twitter

# %%
plt.figure(figsize=(10,7))

plt.title('Opinions Sets Evolution λ = 0.7, δ = 0.6', fontsize = 20)

plt.plot(np.transpose(tot_sets2)[0], label = 'number of politicians in A')

plt.plot(np.transpose(tot_sets2)[1], label = 'number of politicians in O')

plt.plot(np.transpose(tot_sets2)[2], label = 'number of politicians in K')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 plt.figure(figsize=(10,7))
#       3 plt.title('Opinions Sets Evolution λ = 0.7, δ = 0.6', fontsize = 20)
# ----> 5 plt.plot(np.transpose(tot_sets2)[0], label = 'number of politicians in A')
#       7 plt.plot(np.transpose(tot_sets2)[1], label = 'number of politicians in O')
#       9 plt.plot(np.transpose(tot_sets2)[2], label = 'number of politicians in K')
#
# NameError: name 'tot_sets2' is not defined

# %%
parties_evolution = Experimento.visualize_parties_evolution(Plista)

# %%
serie_A, serie_K, serie_O = Experimento.serie_temporal_partido('PT')

# %%
serie_A, serie_K, serie_O = Experimento.serie_temporal_partido('PT')
df_pt = pd.concat([pd.DataFrame(x) for x in [serie_A, serie_K, serie_O]],axis=1)
df_pt.columns = ['Λ','K','Ω']
df_pt.plot(figsize=(10,7),color=['green', 'gray', 'red'],title='PT Opinion evolution \n Lag=%s'%lag)
# Out:
# <Axes: title={'center': 'PT Opinion evolution \n Lag=10'}>

# %%
df_mdb.T.sum().T.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_mdb.T.sum().T.plot()
#
# NameError: name 'df_mdb' is not defined

# %%
serie_A, serie_K, serie_O = Experimento.serie_temporal_partido('MDB')
df_mdb = pd.concat([pd.DataFrame(x) for x in [serie_A, serie_K, serie_O]],axis=1)
df_mdb.columns = ['Λ','K','Ω']
df_mdb.plot(figsize=(10,7),color=['green', 'gray', 'red'],title='MDB Opinion evolution \n Lag=%s'%lag)
# Out:
# <Axes: title={'center': 'MDB Opinion evolution \n Lag=10'}>

# %%
serie_A, serie_K, serie_O = Experimento.serie_temporal_partido('PSL')
df_psl = pd.concat([pd.DataFrame(x) for x in [serie_A, serie_K, serie_O]],axis=1)
df_psl.columns = ['Λ','K','Ω']
df_psl.plot(figsize=(10,7),color=['green', 'gray', 'red'],title='PSL Opinion evolution \n Lag=%s'%lag)
# Out:
# <Axes: title={'center': 'PSL Opinion evolution \n Lag=10'}>

# %%
serie_A, serie_K, serie_O = Experimento.serie_temporal_partido('MDB')
plt.figure(figsize=(10,7))
plt.title('MDB Opinion evolution')
plt.plot(serie_A)
plt.plot(serie_K)
plt.plot(serie_O)

# %%
Experimento.deputados.Partido.count()
# Out:
# 515

# %%
parties_evolution[0].keys()
# Out:
# dict_keys(['AVANTE', 'DC', 'DEM', 'MDB', 'NOVO', 'PATRI', 'PC do B', 'PDT', 'PHS', 'PMN', 'PODE', 'PP', 'PPL', 'PPS', 'PR', 'PRB', 'PROS', 'PRP', 'PSB', 'PSC', 'PSD', 'PSDB', 'PSL', 'PSOL', 'PT', 'PTB', 'PTC', 'PV', 'REDE', 'SD'])

# %%
parties_evolution[-1]['PC do B']
# Out:
# {1: 0, 0: 1, -1: 8}

# %%
tempo=Experimento.time

# %%
plt.figure(figsize=(10,5))
plt.plot(tempo[1:],lens )
plt.gcf().autofmt_xdate()
plt.title('Entrada de novos politicos no debate a partir da data inicial', fontsize=17)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(tempo[1:],lens )
#       3 plt.gcf().autofmt_xdate()
#       4 plt.title('Entrada de novos politicos no debate a partir da data inicial', fontsize=17)
#
# NameError: name 'lens' is not defined

# %%
plt.figure(figsize=(10,5))
plt.plot(tempo[1:],lens )
plt.gcf().autofmt_xdate()
plt.title('Addition of Elected representatives in the current Twitter debate', fontsize=17)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.plot(tempo[1:],lens )
#       3 plt.gcf().autofmt_xdate()
#       4 plt.title('Addition of Elected representatives in the current Twitter debate', fontsize=17)
#
# NameError: name 'lens' is not defined

# %%
pd.DataFrame(changes,
             columns=['a favor',
                      'contra',
                      'indecisos']).plot(figsize=(14,7),
                                         grid=True,
                                         marker='p')
# Out:
# <Axes: >

# %%
pd.DataFrame(changes,
             columns=['A',
                      'O',
                      'K']).plot(figsize=(14,7),
                                         grid=True,
                                         marker='p')
# Out:
# <Axes: >
